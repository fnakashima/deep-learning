# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:14, 2.17MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
# Link for Subsampling
# https://youtu.be/D-xK6gu1ohE?t=5m08s

## Your code here
#print(int_words[:10])
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
#print(word_counts)
#print(total_count)

freqs = {word: count/total_count for word, count in word_counts.items()}
#print(freqs)

p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
#print(p_drop)

# The final subsampled word list
# The reason why random.random() is used here
# We use `random.random()` because that is how Monte carlo sampling works.
# Ref: https://nd101.slack.com/archives/chicago/p1489342920834272
train_words = [word for word in int_words if p_drop[word] < random.random()]
#print(len(train_words))

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
#from random import randint
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    # http://stackoverflow.com/questions/3996904/generate-random-integers-between-0-and-9
    #R = randint(1,window_size)
    R = np.random.randint(1, window_size+1)
    #start_idx = idx - r
    start_idx = idx - R if (idx - R) > 0 else 0
    end_idx = idx + R
    # http://stackoverflow.com/questions/509211/explain-pythons-slice-notation
    target_words = set(words[start_idx:idx] + words[idx+1:end_idx+1])
    #print(target_words)
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    # https://www.tensorflow.org/api_docs/python/tf/placeholder
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features
with train_graph.as_default():
    # https://www.tensorflow.org/tutorials/word2vec
    #embedding = # create embedding weight matrix here
    #embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1.0, 1.0))
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))

    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # https://www.tensorflow.org/tutorials/word2vec
    #softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=1.0 / math.sqrt(n_embedding))) # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))
    softmax_b = tf.Variable(tf.zeros([n_vocab])) # create softmax biases here
    
    # Calculate the loss using negative sampling
    # https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss
    #loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, inputs, n_sampled, n_vocab)
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6854 0.0832 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6198 0.0765 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4935 0.0765 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6227 0.0767 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5116 0.0762 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5126 0.0760 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5734 0.0761 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5345 0.0755 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4740 0.0756 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4513 0.0763 sec/batch
# Nearest to use: hounds, clp, connections, warwick, mesoplodon, verbal, pontiff, taa,
# Nearest to over: vibrations, implication, sitting, meccan, shearwater, mottos, buckets, utero,
# Nearest to at: kappa, knock, upanija, moralistic, greeted, hovg, mikhalkov, circuses,
# Nearest to there: happens, fosters, minoans, tw, reachable, pasp, enamoured, endangered,
# Nearest to have: avc, wah, aggregation, reza, cucurbitaceae, securityfocus, gassan, schaff,
# Nearest to d: reb, bindusara, emails, bellingham, baptise, ads, richard, misleading,
# Nearest to many: punisher, pueblo, delightful, chicanos, spiritualist, smartcard, numidia, religionfacts,
# Nearest to its: smartest, mota, dail, subscriber, porco, identifiers, paganism, iphigenia,
# Nearest to resources: horse, casimir, dinh, eustache, imaged, bigelow, imagined, heroic,
# Nearest to troops: ewan, intersexuality, legitimizing, jamaican, supremely, overzealous, pay, freethinker,
# Nearest to pope: sedative, qwest, hydroelectricity, employed, bowie, comforter, kadima, ambients,
# Nearest to mathematics: redefining, elmhurst, atheos, persephone, pilgrimages, collared, jupiter, corrode,
# Nearest to square: memeplex, goddamn, generalizations, renouncing, sheltered, operand, summer, deserving,
# Nearest to engine: flatted, campaign, ridge, unappreciated, disorders, faded, observables, zemlya,
# Nearest to professional: cornhuskers, classicism, lassen, showgirl, authorial, puritans, dioula, polyn,
# Nearest to discovered: schwenkfeld, notes, critical, wehrmacht, obliterating, lema, standstill, ohm,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4784 0.0776 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4115 0.0768 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3091 0.0765 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2096 0.0766 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1629 0.0770 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1629 0.0766 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1077 0.0763 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0669 0.0776 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0190 0.0766 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9811 0.0766 sec/batch
# Nearest to use: connections, verbal, conference, store, augment, warwick, common, baseball,
# Nearest to over: vibrations, implication, sitting, absent, derived, enhancement, conflict, conducts,
# Nearest to at: kappa, other, something, knock, input, corp, land, finite,
# Nearest to there: happens, endangered, fosters, memory, per, rey, continuation, window,
# Nearest to have: aggregation, compared, securityfocus, avc, addresses, diversion, nature, strangled,
# Nearest to d: reb, richard, universally, misleading, surges, ads, well, onto,
# Nearest to many: punisher, outside, employers, framework, pueblo, walt, delightful, mark,
# Nearest to its: smartest, dail, subscriber, author, predominant, identifiers, mask, sounds,
# Nearest to resources: horse, predominant, eustache, starting, imagined, casimir, thundering, heroic,
# Nearest to troops: pay, energy, intersexuality, jamaican, legitimizing, ewan, supremely, overzealous,
# Nearest to pope: employed, bowie, suffering, sedative, lower, rocks, qwest, enactment,
# Nearest to mathematics: jupiter, guide, paragraph, elmhurst, pilgrimages, drafting, redefining, atheos,
# Nearest to square: generalizations, renouncing, summer, th, concentrated, goddamn, deserving, memeplex,
# Nearest to engine: campaign, ridge, faded, substantial, unappreciated, flatted, three, disorders,
# Nearest to professional: cornhuskers, classicism, browser, lassen, showgirl, observing, allah, kilometers,
# Nearest to discovered: notes, critical, schwenkfeld, european, wehrmacht, wiki, finally, includes,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9085 0.0784 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9099 0.0765 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8937 0.0768 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8698 0.0773 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8131 0.0766 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8340 0.0774 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7890 0.0768 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7833 0.0770 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7806 0.0773 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7758 0.0774 sec/batch
# Nearest to use: augment, verbal, connections, conference, tolerate, grief, warwick, pontiff,
# Nearest to over: vibrations, implication, sitting, derived, absent, photons, informed, flooding,
# Nearest to at: kappa, knock, greeted, corp, finite, something, other, slowest,
# Nearest to there: happens, correlation, fosters, endangered, minoans, downloadable, calculated, rey,
# Nearest to have: wah, avc, aggregation, correlation, schaff, assignment, securityfocus, addresses,
# Nearest to d: reb, richard, surges, ads, universally, emails, bellingham, noting,
# Nearest to many: punisher, delightful, employers, framework, spiritualist, pueblo, mark, cantor,
# Nearest to its: subscriber, dail, smartest, paganism, lindsey, refuted, spaced, identifiers,
# Nearest to resources: horse, imagined, starting, heroic, eustache, predominant, casimir, thundering,
# Nearest to troops: pay, jamaican, energy, autocratic, ewan, intersexuality, articulated, supremely,
# Nearest to pope: jupiter, enactment, lower, bowie, suffering, sedative, overt, employed,
# Nearest to mathematics: paragraph, jupiter, guide, drafting, redefining, elmhurst, models, pilgrimages,
# Nearest to square: generalizations, renouncing, sheltered, deserving, summer, goddamn, concentrated, tasted,
# Nearest to engine: ridge, campaign, flatted, faded, magnetism, unappreciated, disorders, substantial,
# Nearest to professional: browser, cornhuskers, classicism, kilometers, showgirl, lassen, puritans, allah,
# Nearest to discovered: notes, critical, wehrmacht, ohm, wiki, schwenkfeld, includes, european,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8137 0.0774 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7352 0.0776 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7175 0.0769 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6903 0.0784 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7251 0.0776 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7134 0.0777 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6711 0.0772 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7309 0.0777 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6836 0.0777 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6421 0.0771 sec/batch
# Nearest to use: connections, verbal, augment, tolerate, grief, pontiff, hounds, intercepted,
# Nearest to over: vibrations, implication, informed, photons, sitting, conflict, derived, absent,
# Nearest to at: knock, greeted, kappa, lecturing, moralistic, estate, croce, corp,
# Nearest to there: happens, fosters, predate, calculated, correlation, preachers, realize, heijenoort,
# Nearest to have: avc, aggregation, reza, schaff, wah, assignment, assisting, securityfocus,
# Nearest to d: richard, reb, diplomat, surges, john, wavered, noting, ads,
# Nearest to many: punisher, delightful, spiritualist, trait, employers, cantor, framework, pueblo,
# Nearest to its: subscriber, dail, refuted, surrender, lindsey, identifiers, mota, spaced,
# Nearest to resources: horse, imagined, starting, eustache, heroic, casimir, thundering, imaged,
# Nearest to troops: pay, jamaican, autocratic, overzealous, umlauts, ewan, intersexuality, articulated,
# Nearest to pope: sedative, enactment, hungary, particuarly, bowie, urbina, suffering, jupiter,
# Nearest to mathematics: paragraph, redefining, elmhurst, pilgrimages, drafting, jupiter, models, guide,
# Nearest to square: renouncing, generalizations, sheltered, deserving, goddamn, summer, tasted, judeans,
# Nearest to engine: ridge, campaign, flatted, magnetism, unappreciated, heroine, faded, substantial,
# Nearest to professional: cornhuskers, browser, classicism, lassen, showgirl, puritans, kilometers, trumped,
# Nearest to discovered: ohm, notes, critical, schwenkfeld, wehrmacht, wiki, unidentified, standstill,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6595 0.0789 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6594 0.0780 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6133 0.0773 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6281 0.0773 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6155 0.0778 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6356 0.0766 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6118 0.0572 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5450 0.0773 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4887 0.0782 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5054 0.0775 sec/batch
# Nearest to use: connections, verbal, tolerate, apcs, augment, pontiff, analysing, intercepted,
# Nearest to over: utero, vibrations, implication, meccan, informed, sitting, photons, gdp,
# Nearest to at: greeted, knock, lecturing, kappa, vinnie, moralistic, zeus, patchwork,
# Nearest to there: happens, preachers, fosters, predate, minoans, realize, diacritical, correlation,
# Nearest to have: avc, aggregation, reza, schaff, assignment, wah, correlation, securityfocus,
# Nearest to d: diplomat, richard, politician, john, reb, dramatist, wavered, b,
# Nearest to many: trait, punisher, delightful, spiritualist, quarantine, implications, religionfacts, employers,
# Nearest to its: subscriber, dail, mota, refuted, exemption, seacoast, surrender, tipping,
# Nearest to resources: horse, starting, eustache, thundering, casimir, imaged, pollution, subdivision,
# Nearest to troops: umlauts, pay, overzealous, autocratic, slovenia, jamaican, ewan, herschel,
# Nearest to pope: sedative, hungary, daughter, matres, bowie, urbina, historian, particuarly,
# Nearest to mathematics: redefining, paragraph, allocate, elmhurst, accesses, models, pilgrimages, maximian,
# Nearest to square: renouncing, deserving, sheltered, generalizations, tasted, summer, judeans, digging,
# Nearest to engine: ridge, flatted, magnetism, heroine, axp, campaign, unappreciated, interestingly,
# Nearest to professional: lassen, browser, cornhuskers, ib, classicism, showgirl, incantations, stapleton,
# Nearest to discovered: ohm, notes, critical, schwenkfeld, refuges, raffarin, obliterating, standstill,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4854 0.0787 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4811 0.0775 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4793 0.0777 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5441 0.0775 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5010 0.0772 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4997 0.0783 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4695 0.0770 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3981 0.0775 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4516 0.0780 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4229 0.0777 sec/batch
# Nearest to use: apcs, connections, verbal, common, analysing, tolerate, augment, store,
# Nearest to over: gdp, utero, vibrations, implication, conflict, meccan, informed, bracing,
# Nearest to at: knock, greeted, lecturing, patchwork, glas, moralistic, cooks, vinnie,
# Nearest to there: happens, preachers, naturals, diacritical, respectability, minoans, fosters, endangered,
# Nearest to have: avc, aggregation, assignment, ellipsoidal, when, reza, subjected, carefully,
# Nearest to d: diplomat, richard, reb, politician, dietrich, dramatist, john, wavered,
# Nearest to many: delightful, trait, implications, religionfacts, quarantine, conversely, spiritualist, punisher,
# Nearest to its: dail, subscriber, mota, tipping, insuring, exemption, refuted, seacoast,
# Nearest to resources: horse, pollution, subdivision, thundering, eustache, starting, biodiversity, imaged,
# Nearest to troops: pay, slovenia, umlauts, autocratic, overzealous, jamaican, niger, latinate,
# Nearest to pope: daughter, sedative, hungary, signifier, matres, bowie, urbina, historian,
# Nearest to mathematics: allocate, elmhurst, redefining, accesses, paragraph, models, pilgrimages, lambs,
# Nearest to square: generalizations, tasted, sheltered, mi, renouncing, summer, judeans, deserving,
# Nearest to engine: flatted, ridge, heroine, magnetism, axp, periphery, unappreciated, campaign,
# Nearest to professional: lassen, cornhuskers, browser, classicism, games, ib, trumped, incantations,
# Nearest to discovered: ohm, notes, critical, raffarin, obliterating, standstill, schwenkfeld, includes,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4238 0.0788 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4110 0.0778 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4448 0.0773 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3990 0.0777 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4055 0.0777 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4403 0.0775 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3891 0.0780 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3789 0.0773 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4251 0.0777 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3923 0.0780 sec/batch
# Nearest to use: apcs, connections, analysing, augment, tolerate, intercepted, clp, bilbo,
# Nearest to over: gdp, utero, implication, bracing, outpouring, informed, meccan, conflict,
# Nearest to at: knock, westcott, patchwork, moralistic, greeted, glas, kappa, lecturing,
# Nearest to there: happens, preachers, respectability, continuation, diacritical, minoans, naturals, narrators,
# Nearest to have: avc, aggregation, when, subjected, assignment, ellipsoidal, nature, carefully,
# Nearest to d: diplomat, richard, reb, dietrich, dramatist, politician, surges, wavered,
# Nearest to many: religionfacts, spiritualist, trait, implications, delightful, quarantine, employers, criterion,
# Nearest to its: tipping, insuring, mota, subscriber, refuted, exemption, seacoast, dail,
# Nearest to resources: pollution, horse, biodiversity, starting, cotswold, subdivision, imaged, thundering,
# Nearest to troops: pay, slovenia, umlauts, niger, overzealous, autocratic, mercian, normandy,
# Nearest to pope: daughter, hungary, sedative, sister, matres, bowie, signifier, historian,
# Nearest to mathematics: dialectic, allocate, models, mathematical, elmhurst, electromagnetism, accesses, paragraph,
# Nearest to square: generalizations, tasted, sheltered, renouncing, mi, judeans, digging, melting,
# Nearest to engine: flatted, magnetism, axp, ridge, harmonic, unit, heroine, observables,
# Nearest to professional: lassen, browser, cornhuskers, games, classicism, trumped, ib, stapleton,
# Nearest to discovered: ohm, obliterating, fuelling, raffarin, critical, notes, unidentified, lidocaine,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3982 0.0785 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3917 0.0774 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3718 0.0778 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3906 0.0773 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3768 0.0778 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3656 0.0781 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3821 0.0772 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3804 0.0774 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3323 0.0783 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3413 0.0776 sec/batch
# Nearest to use: connections, apcs, augment, analysing, packard, tolerate, childish, clp,
# Nearest to over: gdp, outpouring, kuti, conflict, bracing, implication, utero, totaling,
# Nearest to at: knock, greeted, sanitization, valcourt, moralistic, circuses, vinnie, glas,
# Nearest to there: happens, diacritical, preachers, continuation, minoans, respectability, this, correlation,
# Nearest to have: avc, ellipsoidal, subjected, aggregation, when, reza, correlation, mainly,
# Nearest to d: diplomat, richard, dietrich, reb, surges, politician, dramatist, wavered,
# Nearest to many: religionfacts, spiritualist, trait, quarantine, framework, delightful, employers, implications,
# Nearest to its: tipping, refuted, insuring, exemption, subscriber, mota, seacoast, iphigenia,
# Nearest to resources: pollution, starting, horse, cotswold, biodiversity, subdivision, forestry, endorses,
# Nearest to troops: pay, slovenia, autocratic, umlauts, niger, war, normandy, mercian,
# Nearest to pope: daughter, sedative, bishops, hungary, sister, bowie, monks, matres,
# Nearest to mathematics: dialectic, elmhurst, mathematical, maximian, electromagnetism, isometric, proffered, allocate,
# Nearest to square: generalizations, sheltered, mi, tasted, renouncing, judeans, melting, summer,
# Nearest to engine: flatted, axp, magnetism, ridge, harmonic, heroine, marauders, unit,
# Nearest to professional: lassen, browser, cornhuskers, games, classicism, ib, trumped, stapleton,
# Nearest to discovered: ohm, obliterating, faramir, raffarin, fuelling, lidocaine, critical, unidentified,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3355 0.0788 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3104 0.0776 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3917 0.0784 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3746 0.0777 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3735 0.0772 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2681 0.0772 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3324 0.0777 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3605 0.0772 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2270 0.0783 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3079 0.0770 sec/batch
# Nearest to use: apcs, connections, analysing, augment, packard, common, childish, intercepted,
# Nearest to over: gdp, outpouring, krakatau, kuti, conflict, utero, totaling, icrm,
# Nearest to at: knock, greeted, circuses, valcourt, booker, sanitization, estate, moralistic,
# Nearest to there: happens, minoans, diacritical, preachers, continuation, this, equinoctial, eval,
# Nearest to have: ellipsoidal, avc, aggregation, subjected, tirith, mainly, correlation, when,
# Nearest to d: diplomat, richard, dramatist, dietrich, politician, b, bandleader, reb,
# Nearest to many: religionfacts, spiritualist, quarantine, trait, delightful, gloom, minions, smartcard,
# Nearest to its: tipping, exemption, subscriber, mota, insuring, seacoast, godse, refuted,
# Nearest to resources: pollution, cotswold, starting, timber, biodiversity, forestry, horse, endorses,
# Nearest to troops: army, pay, slovenia, autocratic, war, mercian, umlauts, normandy,
# Nearest to pope: daughter, sedative, bishops, hungary, monks, matres, sister, franciscus,
# Nearest to mathematics: mathematical, dialectic, electromagnetism, elmhurst, proffered, isometric, allocate, maximian,
# Nearest to square: generalizations, mi, sheltered, tasted, meters, renouncing, melting, embarrassingly,
# Nearest to engine: flatted, axp, jet, ridge, magnetism, harmonic, gasoline, heroine,
# Nearest to professional: lassen, cornhuskers, basketball, browser, games, classicism, stapleton, trumped,
# Nearest to discovered: raffarin, ohm, unidentified, faramir, fuelling, catalonia, obliterating, lidocaine,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3045 0.0789 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2815 0.0778 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3333 0.0358 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2407 0.0775 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2328 0.0776 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2296 0.0775 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2482 0.0769 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2131 0.0772 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2494 0.0771 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1752 0.0770 sec/batch
# Nearest to use: connections, apcs, augment, packard, common, analysing, oceanic, intercepted,
# Nearest to over: gdp, outpouring, kuti, krakatau, conflict, utero, totaling, trim,
# Nearest to at: knock, gigantic, greeted, sanitization, folded, estate, circuses, patchwork,
# Nearest to there: happens, minoans, diacritical, continuation, preachers, this, repentant, equinoctial,
# Nearest to have: ellipsoidal, avc, subjected, when, antipodes, aggregation, mainly, tirith,
# Nearest to d: diplomat, dietrich, richard, reb, politician, dramatist, b, sadi,
# Nearest to many: quarantine, gloom, minions, religionfacts, delightful, smartcard, framework, trait,
# Nearest to its: tipping, insuring, exemption, refuted, seacoast, as, subscriber, godse,
# Nearest to resources: pollution, cotswold, forestry, biodiversity, starting, timber, subdivision, horse,
# Nearest to troops: army, pay, war, slovenia, autocratic, umlauts, airborne, exacerbated,
# Nearest to pope: daughter, xi, monks, sedative, bishops, hungary, urbina, benedict,
# Nearest to mathematics: mathematical, dialectic, electromagnetism, elmhurst, isometric, poincar, allocate, proffered,
# Nearest to square: generalizations, mi, sheltered, meters, tasted, melting, embarrassingly, renouncing,
# Nearest to engine: flatted, axp, jet, gasoline, automotive, observables, periphery, campaign,
# Nearest to professional: lassen, cornhuskers, basketball, games, browser, classicism, trumped, email,
# Nearest to discovered: unidentified, catalonia, faramir, obliterating, fuelling, ohm, raffarin, narcolepsy,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2559 0.0784 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2056 0.0773 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2115 0.0775 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1249 0.0781 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1888 0.0783 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1791 0.0774 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1795 0.0770 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2040 0.0776 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1957 0.0775 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1717 0.0777 sec/batch
# Nearest to use: apcs, connections, analysing, common, augment, oceanic, dietary, packard,
# Nearest to over: gdp, outpouring, kuti, krakatau, trim, conflict, utero, idris,
# Nearest to at: sanitization, knock, folded, patchwork, gigantic, braves, estate, valcourt,
# Nearest to there: happens, minoans, diacritical, continuation, this, preachers, equinoctial, repentant,
# Nearest to have: ellipsoidal, avc, subjected, antipodes, aggregation, correlation, when, deriving,
# Nearest to d: diplomat, reb, surges, dietrich, richard, sadi, gaussian, feodor,
# Nearest to many: religionfacts, quarantine, smartcard, gloom, minions, trait, spiritualist, delightful,
# Nearest to its: tipping, insuring, exemption, refuted, as, identifiers, seacoast, godse,
# Nearest to resources: forestry, pollution, biodiversity, cotswold, timber, starting, subdivision, endorses,
# Nearest to troops: army, war, pay, airborne, emden, exacerbated, normandy, umlauts,
# Nearest to pope: monks, bishops, sedative, daughter, xi, benedict, cluny, viii,
# Nearest to mathematics: dialectic, mathematical, poincar, electromagnetism, isometric, elmhurst, allocate, proffered,
# Nearest to square: generalizations, sheltered, mi, tasted, embarrassingly, sheaths, digging, meters,
# Nearest to engine: flatted, jet, axp, gasoline, automotive, observables, campaign, shaft,
# Nearest to professional: lassen, basketball, cornhuskers, browser, games, trumped, slugging, indianapolis,
# Nearest to discovered: unidentified, catalonia, fuelling, faramir, metallic, critical, obliterating, nsh,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1739 0.0787 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2325 0.0774 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1680 0.0779 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1299 0.0772 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1827 0.0775 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2073 0.0774 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2087 0.0767 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1515 0.0774 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1452 0.0776 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1772 0.0774 sec/batch
# Nearest to use: connections, apcs, augment, analysing, common, clp, dietary, packard,
# Nearest to over: outpouring, gdp, krakatau, kuti, runways, three, trim, idris,
# Nearest to at: sanitization, knock, vinnie, paris, westcott, gigantic, estate, valcourt,
# Nearest to there: happens, diacritical, minoans, continuation, this, preachers, lamiaceae, equinoctial,
# Nearest to have: avc, ellipsoidal, antipodes, subjected, aggregation, correlation, deriving, mainly,
# Nearest to d: diplomat, reb, dietrich, feodor, richard, sadi, surges, bandleader,
# Nearest to many: religionfacts, spiritualist, gloom, smartcard, quarantine, minions, trait, ids,
# Nearest to its: tipping, exemption, as, refuted, insuring, identifiers, preparatory, godse,
# Nearest to resources: forestry, pollution, timber, cotswold, biodiversity, subdivision, endorses, looksmart,
# Nearest to troops: army, war, airborne, autocratic, normandy, emden, pay, crushing,
# Nearest to pope: bishops, monks, viii, xi, sister, benedict, sedative, daughter,
# Nearest to mathematics: mathematical, dialectic, poincar, isometric, elmhurst, electromagnetism, proffered, galileo,
# Nearest to square: generalizations, sheltered, tasted, sheaths, embarrassingly, els, melting, uncountably,
# Nearest to engine: flatted, gasoline, axp, jet, campaign, automotive, observables, shaft,
# Nearest to professional: lassen, basketball, cornhuskers, browser, games, trumped, trainer, slugging,
# Nearest to discovered: metallic, unidentified, critical, faramir, catalonia, mev, fuelling, ohm,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2008 0.0784 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1764 0.0777 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2008 0.0764 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1719 0.0774 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1302 0.0773 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1313 0.0776 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1961 0.0778 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1266 0.0778 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1731 0.0775 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2069 0.0773 sec/batch
# Nearest to use: connections, augment, apcs, common, analysing, childish, pronunciation, hounds,
# Nearest to over: outpouring, gdp, kuti, mutual, krakatau, shearwater, conflict, runways,
# Nearest to at: knock, sanitization, paris, vinnie, westcott, braves, estate, greeted,
# Nearest to there: minoans, preachers, continuation, happens, diacritical, this, carelessly, lamiaceae,
# Nearest to have: antipodes, avc, ellipsoidal, subjected, reza, theodosian, mainly, when,
# Nearest to d: diplomat, dietrich, reb, feodor, b, politician, richard, bandleader,
# Nearest to many: religionfacts, spiritualist, gloom, quarantine, smartcard, delightful, trait, minions,
# Nearest to its: exemption, tipping, insuring, preparatory, as, refuted, seacoast, preserve,
# Nearest to resources: forestry, timber, pollution, biodiversity, cotswold, subdivision, horse, starting,
# Nearest to troops: army, autocratic, august, war, crushing, pompey, bataan, emden,
# Nearest to pope: bishops, xi, monks, benedict, viii, sister, vii, daughter,
# Nearest to mathematics: dialectic, mathematical, poincar, elmhurst, proffered, electromagnetism, galileo, isometric,
# Nearest to square: generalizations, sheltered, tasted, mi, els, embarrassingly, digging, cai,
# Nearest to engine: flatted, jet, gasoline, axp, shaft, automotive, patrols, observables,
# Nearest to professional: basketball, lassen, cornhuskers, trumped, trainer, browser, fpss, stapleton,
# Nearest to discovered: unidentified, metallic, faramir, catalonia, critical, nsh, mev, lidocaine,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1911 0.0781 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1117 0.0772 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1477 0.0771 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1583 0.0771 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0563 0.0768 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1583 0.0774 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1249 0.0773 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1430 0.0768 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1916 0.0154 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1436 0.0775 sec/batch
# Nearest to use: connections, apcs, analysing, augment, oceanic, pronunciation, common, childish,
# Nearest to over: gdp, two, three, total, runways, kuti, surpassed, outpouring,
# Nearest to at: knock, braves, sanitization, paris, estate, folded, vinnie, gigantic,
# Nearest to there: minoans, happens, continuation, this, preachers, diacritical, carelessly, saddened,
# Nearest to have: ellipsoidal, avc, antipodes, subjected, correlation, is, mainly, glaciology,
# Nearest to d: diplomat, dietrich, reb, feodor, politician, sadi, ivanovich, eldridge,
# Nearest to many: religionfacts, spiritualist, quarantine, trait, punisher, ids, smartcard, minions,
# Nearest to its: as, tipping, exemption, insuring, preparatory, identifiers, the, catalan,
# Nearest to resources: forestry, timber, cotswold, biodiversity, pollution, starting, horse, subdivision,
# Nearest to troops: army, war, autocratic, emden, pbsuccess, crushing, abdur, normandy,
# Nearest to pope: benedict, xi, vii, bishops, viii, franciscus, urbina, monks,
# Nearest to mathematics: dialectic, mathematical, poincar, elmhurst, electromagnetism, proffered, galileo, monmouth,
# Nearest to square: generalizations, sheltered, tasted, els, maori, cai, mi, embarrassingly,
# Nearest to engine: jet, flatted, gasoline, automotive, axp, shaft, patrols, raf,
# Nearest to professional: cornhuskers, basketball, lassen, trumped, browser, fpss, trainer, ims,
# Nearest to discovered: metallic, unidentified, critical, catalonia, faramir, nsh, mev, narcolepsy,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0675 0.0781 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0690 0.0774 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0950 0.0774 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0470 0.0769 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0929 0.0774 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0284 0.0782 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0781 0.0765 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0883 0.0774 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1242 0.0775 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0315 0.0778 sec/batch
# Nearest to use: connections, apcs, augment, common, oceanic, analysing, childish, pronunciation,
# Nearest to over: gdp, two, three, outpouring, total, krakatau, surpassed, kuti,
# Nearest to at: sanitization, knock, braves, estate, folded, gigantic, vinnie, paris,
# Nearest to there: minoans, continuation, this, diacritical, happens, preachers, sedative, carelessly,
# Nearest to have: ellipsoidal, avc, antipodes, percentages, subjected, is, when, tirith,
# Nearest to d: diplomat, dietrich, reb, feodor, sadi, gaussian, politician, eldridge,
# Nearest to many: ids, religionfacts, quarantine, smartcard, include, punisher, spiritualist, and,
# Nearest to its: as, tipping, insuring, preparatory, the, exemption, identifiers, catalan,
# Nearest to resources: forestry, timber, cotswold, biodiversity, pollution, looksmart, starting, subdivision,
# Nearest to troops: army, war, emden, abdur, pompey, airborne, normandy, autocratic,
# Nearest to pope: vii, vi, xi, benedict, viii, bishops, cluny, sister,
# Nearest to mathematics: mathematical, dialectic, poincar, elmhurst, electromagnetism, proffered, monmouth, isometric,
# Nearest to square: generalizations, sheltered, mi, ky, maori, cai, embarrassingly, tasted,
# Nearest to engine: flatted, jet, gasoline, automotive, axp, shaft, patrols, nchen,
# Nearest to professional: basketball, cornhuskers, lassen, trumped, trainer, fpss, browser, dispensing,
# Nearest to discovered: metallic, unidentified, catalonia, mev, critical, faramir, humanoid, nsh,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0092 0.0788 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0658 0.0783 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0395 0.0769 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0631 0.0771 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0642 0.0776 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0880 0.0776 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0583 0.0776 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1183 0.0776 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0881 0.0774 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0439 0.0770 sec/batch
# Nearest to use: connections, apcs, common, augment, dietary, analysing, pronunciation, childish,
# Nearest to over: gdp, two, total, outpouring, surpassed, closures, three, mutual,
# Nearest to at: sanitization, braves, knock, vinnie, estate, westcott, paris, pistons,
# Nearest to there: this, continuation, minoans, happens, carelessly, diacritical, geocachers, have,
# Nearest to have: ellipsoidal, avc, antipodes, is, subjected, percentages, glaciology, evolved,
# Nearest to d: diplomat, dietrich, reb, gaussian, feodor, sadi, surges, ivanovich,
# Nearest to many: religionfacts, trait, spiritualist, minions, include, ids, smartcard, quarantine,
# Nearest to its: as, tipping, insuring, identifiers, catalan, the, preparatory, also,
# Nearest to resources: forestry, timber, cotswold, biodiversity, pollution, looksmart, project, acquisition,
# Nearest to troops: army, war, legitimizing, pompey, dooley, abdur, normandy, autocratic,
# Nearest to pope: papal, bishops, cluny, vi, benedict, lateran, edom, vii,
# Nearest to mathematics: mathematical, poincar, dialectic, electromagnetism, elmhurst, logarithm, proffered, isometric,
# Nearest to square: generalizations, embarrassingly, uncountably, sheltered, ky, digging, tasted, els,
# Nearest to engine: gasoline, flatted, jet, automotive, axp, shaft, piston, patrols,
# Nearest to professional: basketball, cornhuskers, trumped, lassen, trainer, fpss, browser, ims,
# Nearest to discovered: metallic, unidentified, mev, critical, nsh, humanoid, catalonia, faramir,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0740 0.0782 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0805 0.0772 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0876 0.0774 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0378 0.0772 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0603 0.0777 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0818 0.0775 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0817 0.0769 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0659 0.0771 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0929 0.0775 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0839 0.0769 sec/batch
# Nearest to use: connections, apcs, augment, common, pronunciation, dietary, packard, analysing,
# Nearest to over: two, gdp, closures, surpassed, three, total, multiplier, runways,
# Nearest to at: sanitization, paris, braves, knock, estate, memorial, vinnie, isar,
# Nearest to there: this, continuation, diacritical, assigning, minoans, have, happens, carelessly,
# Nearest to have: avc, antipodes, ellipsoidal, subjected, is, nica, when, there,
# Nearest to d: diplomat, reb, dietrich, feodor, sadi, gaussian, surges, officiel,
# Nearest to many: religionfacts, trait, spiritualist, quarantine, ids, rental, moors, punisher,
# Nearest to its: as, the, preparatory, insuring, tipping, catalan, ministers, grundgesetz,
# Nearest to resources: forestry, timber, cotswold, biodiversity, looksmart, project, endorses, pollution,
# Nearest to troops: army, war, autocratic, august, abdur, pompey, frogmen, crushing,
# Nearest to pope: bishops, papal, vii, lateran, viii, vi, benedict, cluny,
# Nearest to mathematics: poincar, mathematical, dialectic, elmhurst, galileo, proffered, electromagnetism, maximian,
# Nearest to square: generalizations, embarrassingly, sheltered, els, uncountably, torrents, tasted, cai,
# Nearest to engine: gasoline, flatted, jet, automotive, shaft, axp, patrols, observables,
# Nearest to professional: basketball, cornhuskers, trumped, trainer, fpss, lassen, pundit, dispensing,
# Nearest to discovered: metallic, unidentified, critical, mev, catalonia, nsh, faramir, habitation,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0467 0.0785 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0194 0.0773 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0602 0.0777 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0872 0.0773 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0409 0.0772 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1307 0.0778 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1134 0.0772 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0379 0.0775 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0432 0.0774 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0681 0.0765 sec/batch
# Nearest to use: connections, apcs, common, augment, pronunciation, vocalized, dietary, analysing,
# Nearest to over: gdp, two, surpassed, closures, outpouring, total, three, multiplier,
# Nearest to at: braves, sanitization, paris, knock, vinnie, pistons, estate, valcourt,
# Nearest to there: continuation, this, have, carelessly, exempted, minoans, assigning, happens,
# Nearest to have: ellipsoidal, is, avc, antipodes, subjected, compared, there, correlation,
# Nearest to d: diplomat, reb, dietrich, feodor, sadi, gaussian, surges, politician,
# Nearest to many: ids, trait, fusiliers, spiritualist, religionfacts, quarantine, smartcard, include,
# Nearest to its: as, tipping, insuring, catalan, preparatory, the, negligible, ministers,
# Nearest to resources: forestry, timber, cotswold, biodiversity, pollution, complying, looksmart, endorses,
# Nearest to troops: army, frogmen, pompey, autocratic, war, august, abdur, burnside,
# Nearest to pope: bishops, viii, vii, lateran, benedict, papal, sedative, vi,
# Nearest to mathematics: poincar, dialectic, mathematical, elmhurst, proffered, galileo, maximian, logarithm,
# Nearest to square: generalizations, embarrassingly, sheltered, uncountably, ky, els, boulevard, torrents,
# Nearest to engine: jet, gasoline, flatted, automotive, shaft, axp, piston, nchen,
# Nearest to professional: cornhuskers, basketball, trainer, fpss, lassen, trumped, pundit, prokhorov,
# Nearest to discovered: metallic, unidentified, nsh, critical, mev, catalonia, faramir, discovery,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9808 0.0785 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0297 0.0771 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0239 0.0776 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0558 0.0769 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0930 0.0774 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0509 0.0717 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0119 0.0775 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9846 0.0767 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0169 0.0766 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9858 0.0773 sec/batch
# Nearest to use: connections, apcs, common, modern, augment, dietary, vocalized, pronunciation,
# Nearest to over: gdp, closures, total, surpassed, two, multiplier, runways, outpouring,
# Nearest to at: braves, paris, knock, pistons, comprehensively, memorial, estate, ircnet,
# Nearest to there: this, minoans, continuation, have, diacritical, carelessly, sedative, exempted,
# Nearest to have: ellipsoidal, is, antipodes, avc, in, when, subjected, there,
# Nearest to d: diplomat, feodor, reb, dietrich, sadi, politician, b, dramatist,
# Nearest to many: spiritualist, punisher, ids, fusiliers, trait, quarantine, liberalized, include,
# Nearest to its: as, tipping, identifiers, insuring, catalan, also, preparatory, the,
# Nearest to resources: forestry, timber, cotswold, horse, looksmart, complying, acquisition, stances,
# Nearest to troops: army, frogmen, pompey, burnside, bataan, abdur, dooley, icsu,
# Nearest to pope: vii, viii, vi, xi, benedict, papal, arched, bishops,
# Nearest to mathematics: mathematical, poincar, dialectic, elmhurst, proffered, galileo, electromagnetism, logarithm,
# Nearest to square: generalizations, embarrassingly, ky, boulevard, els, uncountably, torrents, cafes,
# Nearest to engine: jet, gasoline, flatted, automotive, axp, shaft, thorough, piston,
# Nearest to professional: basketball, cornhuskers, trainer, lassen, fpss, trumped, prokhorov, pundit,
# Nearest to discovered: metallic, unidentified, mev, catalonia, nsh, critical, humanoid, narcolepsy,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9805 0.0782 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9396 0.0768 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0326 0.0762 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0228 0.0773 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0267 0.0772 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9899 0.0767 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9256 0.0773 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9368 0.0770 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9459 0.0776 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0136 0.0770 sec/batch
# Nearest to use: connections, common, modern, dietary, apcs, pronunciation, vocalized, augment,
# Nearest to over: gdp, two, closures, surpassed, total, multiplier, five, three,
# Nearest to at: braves, estate, pistons, valcourt, paris, folded, sanitization, thoroughbred,
# Nearest to there: this, have, continuation, exempted, undetermined, is, assigning, carelessly,
# Nearest to have: is, ellipsoidal, in, there, avc, percentages, antipodes, subjected,
# Nearest to d: reb, diplomat, feodor, surges, sadi, dietrich, gaussian, tcs,
# Nearest to many: spiritualist, punisher, trait, quarantine, and, include, ids, fusiliers,
# Nearest to its: as, identifiers, catalan, also, tipping, the, preparatory, insuring,
# Nearest to resources: forestry, timber, horse, cotswold, mining, acquisition, complying, looksmart,
# Nearest to troops: army, frogmen, pompey, pbsuccess, abdur, burnside, bataan, supremely,
# Nearest to pope: lateran, vii, papal, benedict, sedative, viii, bishops, arched,
# Nearest to mathematics: poincar, dialectic, mathematical, elmhurst, proffered, logarithm, satirist, galileo,
# Nearest to square: generalizations, els, embarrassingly, uncountably, ky, torrents, boulevard, cafes,
# Nearest to engine: jet, flatted, gasoline, automotive, axp, shaft, thorough, nchen,
# Nearest to professional: basketball, cornhuskers, trainer, fpss, lassen, trumped, prokhorov, psa,
# Nearest to discovered: metallic, catalonia, unidentified, mev, nsh, critical, humanoid, decompression,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0069 0.0784 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0163 0.0772 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9755 0.0770 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9886 0.0772 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0419 0.0779 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9505 0.0770 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9931 0.0770 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0018 0.0769 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9995 0.0772 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9805 0.0771 sec/batch
# Nearest to use: common, connections, apcs, dietary, pronunciation, modern, augment, psych,
# Nearest to over: closures, two, multiplier, total, gdp, runways, completing, surpassed,
# Nearest to at: braves, pistons, paris, estate, valcourt, vinnie, salzburg, memorial,
# Nearest to there: this, have, undetermined, continuation, exempted, carelessly, assigning, diacritical,
# Nearest to have: is, there, avc, ellipsoidal, antipodes, when, percentages, subjected,
# Nearest to d: diplomat, reb, feodor, dietrich, ivanovich, tcs, sadi, officiel,
# Nearest to many: spiritualist, punisher, religionfacts, fusiliers, trait, include, rental, adjust,
# Nearest to its: as, identifiers, tipping, catalan, preparatory, also, the, asset,
# Nearest to resources: forestry, timber, mining, complying, enthusiast, horse, cotswold, acquisition,
# Nearest to troops: army, burnside, pompey, frogmen, abdur, bataan, pbsuccess, legitimizing,
# Nearest to pope: lateran, papal, sedative, bishops, vii, benedict, viii, arched,
# Nearest to mathematics: mathematical, poincar, dialectic, elmhurst, proffered, galileo, satirist, logarithm,
# Nearest to square: generalizations, uncountably, embarrassingly, els, garden, citizen, torrents, boulevard,
# Nearest to engine: jet, gasoline, flatted, automotive, shaft, axp, thorough, cemeteries,
# Nearest to professional: basketball, cornhuskers, trainer, fpss, trumped, pundit, lassen, prokhorov,
# Nearest to discovered: metallic, mev, catalonia, unidentified, nsh, humanoid, critical, lingering,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0012 0.0784 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9839 0.0767 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9790 0.0767 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0164 0.0769 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0188 0.0774 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0053 0.0774 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9768 0.0774 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9511 0.0771 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9565 0.0767 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0149 0.0774 sec/batch
# Nearest to use: connections, common, modern, apcs, dietary, this, industries, pronunciation,
# Nearest to over: closures, two, three, total, five, gdp, surpassed, multiplier,
# Nearest to at: paris, comprehensively, estate, salzburg, pistons, braves, valcourt, vinnie,
# Nearest to there: this, have, exempted, minoans, assigning, carelessly, continuation, diacritical,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8442 0.0781 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8727 0.0770 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8916 0.0775 sec/batch
# Nearest to use: used, mh, common, have, modern, reliable, psych, augment,
# Nearest to over: five, two, three, closures, one, unital, zero, years,
# Nearest to at: to, the, of, was, from, braves, estate, about,
# Nearest to there: have, this, more, exempted, out, is, carelessly, in,
# Nearest to have: been, some, there, in, that, not, and, most,
# Nearest to d: reb, feodor, mui, kroeber, dramatist, internorth, behn, armenian,
# Nearest to many: include, are, were, notably, various, and, both, spiritualist,
# Nearest to its: as, the, is, in, also, it, kigamboni, a,
# Nearest to resources: enthusiast, woodland, resource, forestry, mining, complying, pastures, hazards,
# Nearest to troops: burnside, frogmen, army, alas, pompey, clemson, cannae, rzburg,
# Nearest to pope: papal, lateran, apostolicae, arched, vii, xvi, hieria, sedative,
# Nearest to mathematics: universitet, upto, batted, satirist, doctorate, elmhurst, maximian, bulfinch,
# Nearest to square: bicyclists, els, generalizations, garden, cai, harlem, torrents, boulevard,
# Nearest to engine: engines, automotive, thorough, exhausts, gasoline, jet, lenoir, shaft,
# Nearest to professional: basketball, fpss, discouraged, cornhuskers, voracious, osteopathic, emden, intravenous,
# Nearest to discovered: discovery, decompression, was, metallic, walcott, catalonia, minsk, found,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8380 0.0782 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8675 0.0774 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8554 0.0769 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8516 0.0780 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8640 0.0774 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8844 0.0768 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8484 0.0767 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8347 0.0768 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9013 0.0777 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8430 0.0772 sec/batch
# Nearest to use: used, mh, have, connections, common, modern, apcs, psych,
# Nearest to over: five, one, three, zero, two, closures, four, unital,
# Nearest to at: to, the, of, estate, after, from, was, pistons,
# Nearest to there: have, more, this, is, exempted, out, same, carelessly,
# Nearest to have: been, some, there, in, not, most, few, however,
# Nearest to d: reb, feodor, internorth, kroeber, armenian, mui, vance, bindusara,
# Nearest to many: were, include, notably, are, various, burg, spiritualist, and,
# Nearest to its: as, the, in, also, is, a, it, s,
# Nearest to resources: enthusiast, woodland, natural, ore, forestry, timber, pastures, hazards,
# Nearest to troops: burnside, frogmen, army, pompey, alas, abdur, rzburg, cannae,
# Nearest to pope: papal, lateran, apostolicae, arched, vii, viii, hieria, sedative,
# Nearest to mathematics: universitet, upto, batted, satirist, doctorate, maximian, elmhurst, pilgrimages,
# Nearest to square: bicyclists, generalizations, els, rebellious, ken, citizen, uncountably, torrents,
# Nearest to engine: engines, automotive, thorough, exhausts, gasoline, jet, lenoir, kandy,
# Nearest to professional: basketball, fpss, discouraged, cornhuskers, voracious, auspices, lepton, pundit,
# Nearest to discovered: discovery, metallic, decompression, found, walcott, catalonia, minsk, was,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8599 0.0780 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8455 0.0762 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8345 0.0776 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8063 0.0768 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8947 0.0774 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8390 0.0783 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9549 0.0775 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8808 0.0778 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9034 0.0770 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8230 0.0782 sec/batch
# Nearest to use: used, mh, have, common, modern, conformed, sinhalese, apcs,
# Nearest to over: one, five, three, zero, two, four, years, closures,
# Nearest to at: to, the, of, in, estate, after, was, from,
# Nearest to there: have, more, exempted, out, carelessly, this, hispanics, is,
# Nearest to have: been, some, there, in, most, although, not, few,
# Nearest to d: reb, feodor, kroeber, dramatist, vance, b, mengele, mui,
# Nearest to many: were, include, notably, are, various, including, and, burg,
# Nearest to its: the, as, in, also, is, it, kigamboni, tachelhit,
# Nearest to resources: enthusiast, natural, woodland, ore, hazards, pastures, timber, manganese,
# Nearest to troops: burnside, frogmen, alas, army, galina, pompey, abdur, bataan,
# Nearest to pope: papal, apostolicae, lateran, arched, vii, betty, viii, hieria,
# Nearest to mathematics: universitet, upto, batted, satirist, doctorate, maximian, bulfinch, elmhurst,
# Nearest to square: bicyclists, generalizations, ken, citizen, els, cai, logarithm, harlem,
# Nearest to engine: engines, jet, automotive, thorough, exhausts, gasoline, lenoir, shaft,
# Nearest to professional: basketball, fpss, discouraged, cornhuskers, voracious, pundit, paradigmatic, societies,
# Nearest to discovered: discovery, decompression, metallic, found, minsk, walcott, apparently, catalonia,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8099 0.0778 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8611 0.0773 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7813 0.0777 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8803 0.0770 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8389 0.0777 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8742 0.0769 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8994 0.0447 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8129 0.0768 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8261 0.0772 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8447 0.0769 sec/batch
# Nearest to use: used, mh, modern, conformed, common, sinhalese, dispenser, reliable,
# Nearest to over: five, years, two, one, closures, three, zero, four,
# Nearest to at: to, the, of, was, in, after, from, his,
# Nearest to there: have, exempted, carelessly, is, more, incarnated, this, hispanics,
# Nearest to have: been, some, there, in, however, although, few, not,
# Nearest to d: reb, feodor, b, dramatist, mengele, diplomat, politician, kroeber,
# Nearest to many: include, notably, various, are, were, such, notable, both,
# Nearest to its: as, the, in, is, also, it, kigamboni, a,
# Nearest to resources: enthusiast, woodland, ore, natural, pastures, resource, manganese, hazards,
# Nearest to troops: burnside, frogmen, alas, army, pompey, galina, abdur, cannae,
# Nearest to pope: papal, arched, apostolicae, lateran, betty, vi, xvi, vii,
# Nearest to mathematics: universitet, upto, batted, doctorate, satirist, maximian, bulfinch, elmhurst,
# Nearest to square: bicyclists, ken, citizen, els, generalizations, torrents, cai, logarithm,
# Nearest to engine: engines, automotive, jet, lenoir, gasoline, exhausts, thorough, kandy,
# Nearest to professional: basketball, fpss, discouraged, voracious, cornhuskers, aneurysm, ids, intravenous,
# Nearest to discovered: found, discovery, metallic, decompression, was, walcott, catalonia, minsk,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8219 0.0781 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8185 0.0772 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8342 0.0779 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8053 0.0768 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8674 0.0775 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8106 0.0769 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8857 0.0780 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7568 0.0772 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8282 0.0775 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7833 0.0771 sec/batch
# Nearest to use: used, mh, common, modern, have, reliable, sinhalese, conformed,
# Nearest to over: five, one, two, three, zero, years, closures, four,
# Nearest to at: to, the, of, from, was, in, after, estate,
# Nearest to there: have, is, more, of, this, exempted, residing, carelessly,
# Nearest to have: been, some, there, in, that, not, even, although,
# Nearest to d: reb, feodor, armenian, internorth, southwestern, dramatist, mengele, vocative,
# Nearest to many: include, are, notably, various, and, some, called, including,
# Nearest to its: as, in, the, is, also, it, a, s,
# Nearest to resources: enthusiast, woodland, natural, resource, manganese, ore, forestry, pastures,
# Nearest to troops: frogmen, burnside, army, alas, pompey, galina, cannae, professional,
# Nearest to pope: papal, arched, apostolicae, lateran, xvi, hieria, betty, qwest,
# Nearest to mathematics: universitet, batted, satirist, upto, doctorate, maximian, bulfinch, arbitrary,
# Nearest to square: bicyclists, ken, els, citizen, generalizations, harlem, garden, logarithm,
# Nearest to engine: engines, automotive, jet, exhausts, lenoir, thorough, kandy, axp,
# Nearest to professional: basketball, fpss, discouraged, cornhuskers, voracious, aneurysm, ids, auspices,
# Nearest to discovered: found, discovery, catalonia, walcott, apparently, metallic, decompression, was,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7604 0.0786 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8266 0.0776 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8521 0.0773 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7994 0.0778 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8193 0.0773 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9168 0.0779 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8429 0.0773 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8115 0.0771 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8140 0.0769 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8646 0.0772 sec/batch
# Nearest to use: used, mh, have, common, conformed, reliable, by, to,
# Nearest to over: five, one, two, three, zero, years, four, closures,
# Nearest to at: to, the, of, in, after, estate, was, from,
# Nearest to there: have, this, exempted, out, three, of, is, carelessly,
# Nearest to have: been, some, there, in, and, although, most, however,
# Nearest to d: reb, feodor, armenian, dramatist, internorth, standardized, kroeber, airbase,
# Nearest to many: include, are, notably, were, and, various, including, spiritualist,
# Nearest to its: as, in, the, also, is, a, it, which,
# Nearest to resources: enthusiast, ore, woodland, manganese, natural, resource, hazards, timber,
# Nearest to troops: burnside, frogmen, alas, galina, clemson, professional, pompey, rzburg,
# Nearest to pope: papal, arched, apostolicae, lateran, xvi, hieria, qwest, betty,
# Nearest to mathematics: universitet, batted, satirist, upto, doctorate, maximian, arbitrary, elmhurst,
# Nearest to square: bicyclists, ken, els, rebellious, generalizations, harlem, citizen, winchell,
# Nearest to engine: engines, automotive, exhausts, thorough, jet, lenoir, gasoline, piston,
# Nearest to professional: discouraged, fpss, basketball, cornhuskers, voracious, aneurysm, auspices, avidly,
# Nearest to discovered: discovery, found, was, transuranic, catalonia, walcott, corning, metallic,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8650 0.0781 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8477 0.0773 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8015 0.0776 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8240 0.0771 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8403 0.0766 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8430 0.0776 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8196 0.0778 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8556 0.0770 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8103 0.0775 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8379 0.0774 sec/batch
# Nearest to use: used, mh, by, common, have, to, and, this,
# Nearest to over: one, five, three, two, four, zero, six, eight,
# Nearest to at: to, the, of, in, from, was, after, then,
# Nearest to there: have, this, more, is, in, out, them, with,
# Nearest to have: been, some, there, in, however, although, not, that,
# Nearest to d: reb, feodor, internorth, armenian, airbase, benelli, dramatist, deference,
# Nearest to many: include, are, notably, were, and, ones, have, with,
# Nearest to its: in, as, the, also, a, is, from, it,
# Nearest to resources: enthusiast, natural, woodland, resource, manganese, hazards, ore, complying,
# Nearest to troops: frogmen, burnside, alas, pompey, clemson, cannae, army, galina,
# Nearest to pope: papal, arched, apostolicae, lateran, vii, xvi, hieria, betty,
# Nearest to mathematics: universitet, batted, satirist, upto, doctorate, maximian, arbitrary, elmhurst,
# Nearest to square: bicyclists, ken, els, logarithm, citizen, generalizations, rebellious, harlem,
# Nearest to engine: engines, automotive, exhausts, gasoline, thorough, lenoir, kandy, newcomen,
# Nearest to professional: fpss, discouraged, voracious, cornhuskers, basketball, ids, aneurysm, auspices,
# Nearest to discovered: discovery, found, was, apparently, transuranic, walcott, catalonia, minsk,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8646 0.0784 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8368 0.0775 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9046 0.0772 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9008 0.0772 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8731 0.0771 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8515 0.0772 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7570 0.0764 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8379 0.0770 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7062 0.0776 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8587 0.0780 sec/batch
# Nearest to use: used, mh, to, have, common, and, modern, by,
# Nearest to over: two, five, three, one, zero, years, four, six,
# Nearest to at: to, of, the, in, estate, was, after, from,
# Nearest to there: have, more, is, of, are, this, out, hispanics,
# Nearest to have: been, some, there, in, however, although, and, has,
# Nearest to d: dramatist, feodor, kroeber, b, zach, mengele, reb, airbase,
# Nearest to many: include, were, notably, are, various, notable, have, including,
# Nearest to its: as, in, the, also, is, a, which, it,
# Nearest to resources: enthusiast, woodland, hazards, resource, pastures, timber, complying, manganese,
# Nearest to troops: burnside, alas, frogmen, army, galina, cannae, sempronius, heaviest,
# Nearest to pope: papal, arched, apostolicae, lateran, betty, xvi, vii, hieria,
# Nearest to mathematics: universitet, upto, satirist, doctorate, batted, maximian, arbitrary, quivering,
# Nearest to square: bicyclists, ken, els, generalizations, citizen, boulevard, kilometres, logarithm,
# Nearest to engine: engines, automotive, exhausts, gasoline, kandy, lenoir, thorough, newcomen,
# Nearest to professional: fpss, cornhuskers, voracious, discouraged, basketball, aneurysm, auspices, avidly,
# Nearest to discovered: was, found, discovery, apparently, walcott, catalonia, decompression, minsk,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8427 0.0787 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8293 0.0772 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
