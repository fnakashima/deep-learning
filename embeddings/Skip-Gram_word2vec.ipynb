# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

# http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf
threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
from random import randint

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = randint(1, window_size+1)
    
    past_idx = idx - R
    if past_idx < 0:
        past_idx = 0
    past_words = words[past_idx:idx]
    
    future_idx = idx + R + 1
    future_words = words[idx+1:future_idx]
    
#     target_words = list()
#     target_words.append(past_words)
#     target_words.append(future_words)
#     return target_words

    # Remove any duplications
    target_words = set(past_words + future_words)
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1, name='embedding')
    
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs, name='embed')

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6585 0.1858 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6324 0.1786 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4763 0.1743 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6550 0.1760 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5486 0.1764 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5778 0.1744 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5956 0.1731 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5655 0.1973 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5712 0.1855 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5252 0.1833 sec/batch
# Nearest to a: susie, ferns, attenuated, arnage, chupacabras, judean, hill, gerber,
# Nearest to than: alka, gilberts, shavuot, atm, royalty, checklist, sedgewick, contest,
# Nearest to history: macmullen, payment, jains, frente, otters, galante, papua, rousing,
# Nearest to were: ebb, telstra, filling, naively, riba, bahmani, batsman, vegas,
# Nearest to can: novello, lahr, xli, undisclosed, reimagined, dudley, sunga, bunter,
# Nearest to is: metal, venereal, leopards, javan, disliked, bram, similarly, obliged,
# Nearest to was: ruggles, lag, evaporator, joannes, stroessner, mural, fascism, busts,
# Nearest to not: subfamilia, arduous, cupbearer, compilers, ghz, testaments, transmissive, disappointing,
# Nearest to freedom: foyle, secret, bq, maltese, hoard, hecht, lansing, unquestioned,
# Nearest to pope: eponyms, massage, jaundice, lemonade, danilo, criminology, divergent, kvac,
# Nearest to behind: zy, whois, graveyards, petit, tli, gonzalo, tnt, reforms,
# Nearest to police: tasking, drunks, senators, islands, conomique, spaced, azaria, excessive,
# Nearest to applied: directory, hydrological, starters, gautier, secreting, atc, dyer, hung,
# Nearest to issue: gregor, act, peake, minimally, inhomogeneous, corbusier, frankenchrist, epidemics,
# Nearest to liberal: oatmeal, solo, inventors, rulership, kadena, jehoash, esl, monopolize,
# Nearest to channel: ammo, stravinsky, meanwhile, himself, rhead, rios, estimating, eelam,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5804 0.1781 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.5683 0.1691 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.5088 0.1695 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.4679 0.1691 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.4667 0.1683 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.5071 0.1667 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.4563 0.1681 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.4523 0.1666 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.4242 0.1638 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.4429 0.1641 sec/batch
# Nearest to a: paran, bernese, lonesome, volkssturm, stylistically, mccann, segmentation, alga,
# Nearest to than: legation, propanone, statue, behalf, icosahedral, cartwright, transmutation, trenches,
# Nearest to history: kie, borsuk, distressing, palaeolithic, homegrown, grained, yoda, drang,
# Nearest to were: panzer, tuck, lincolnshire, autres, quin, peace, weave, prefects,
# Nearest to can: excepted, kullervo, indefensible, snowstorms, articulated, audacious, elitism, appeals,
# Nearest to is: curium, iia, balla, stenosis, stifles, incubators, lancashire, deflagration,
# Nearest to was: golden, venous, predictor, investigating, urge, silents, aldo, ga,
# Nearest to not: food, inflicting, theoretically, disseminating, steels, chaplains, unfounded, widukind,
# Nearest to freedom: romain, adulthood, dorn, naa, strathcona, cheer, sparks, mississippi,
# Nearest to pope: democratisation, thermo, favorite, published, interlacing, diefenbaker, codex, crankshafts,
# Nearest to behind: dominus, guez, arbiter, november, goss, sedimentation, geats, undergoing,
# Nearest to police: sayle, ideation, testifying, equinoctial, rubles, scanlon, bromley, deserts,
# Nearest to applied: commissars, killebrew, parkhurst, began, attracted, invoke, isn, seljuk,
# Nearest to issue: swivel, mamoru, fuck, filamentous, mumonkan, elapsed, andalus, tou,
# Nearest to liberal: jacky, rakolta, responsibility, jos, powerpuff, turkey, mudders, mckeon,
# Nearest to channel: groot, mitt, conditionals, coretta, seedless, tina, loka, flutes,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 5.4933 0.1687 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 5.4242 0.1656 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 5.4088 0.1642 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 5.3961 0.1648 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 5.3182 0.1653 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 5.4171 0.1648 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 5.3901 0.1655 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 5.3374 0.1652 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 5.3382 0.1841 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 5.3482 0.1845 sec/batch
# Nearest to a: amoraim, haarlem, dune, samaras, modernism, azam, spiked, antananarivo,
# Nearest to than: mutilation, complicated, putsch, quintet, hotham, trimmed, indifferent, figured,
# Nearest to history: cpu, weighted, selvin, cksburg, shimizu, parcels, abundance, tsunami,
# Nearest to were: blindness, hes, margot, gneisses, skills, abominations, validation, maiman,
# Nearest to can: mosley, professors, adelaide, grainger, barra, castillo, haste, litani,
# Nearest to is: neander, cherubim, typological, horthy, unconditionally, don, fecture, hoodlum,
# Nearest to was: rab, cryptanalysis, owner, situs, foe, prepositioning, magistrates, determined,
# Nearest to not: donnell, develop, kenyan, thickly, ribald, fissile, expellees, nongovernmental,
# Nearest to freedom: piled, boney, interruptus, cidr, sara, leavitt, rhymed, waco,
# Nearest to pope: wz, shoots, rambla, finance, locative, kalahari, nicholls, lichfield,
# Nearest to behind: pittsburg, stake, raised, atwater, forgent, suggesting, demotic, gown,
# Nearest to police: favouring, revising, unsecured, chapin, panpsychism, sandwich, clerihew, coalition,
# Nearest to applied: padishah, anthroposophy, alkaline, vergina, benchmark, bernini, diodorus, sometime,
# Nearest to issue: databank, immaterial, escaping, mca, corfu, cornets, aga, marathon,
# Nearest to liberal: diogenes, devarim, mandola, canids, obs, binky, shrinks, homininae,
# Nearest to channel: partitions, prospecting, amon, hampering, blockade, frowned, samarkand, challenges,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 5.3625 0.1852 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 5.2957 0.1874 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 5.3861 0.1850 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 5.3282 0.1807 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 5.3666 0.1778 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 5.2619 0.1818 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 5.2890 0.1897 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 5.2557 0.1838 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 5.2685 0.1712 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 5.2585 0.1709 sec/batch
# Nearest to a: patan, einar, crb, malayo, matador, fz, coworkers, hollow,
# Nearest to than: glycemic, unconfirmed, unafraid, dans, kurt, vlcd, lodges, maxine,
# Nearest to history: australians, bayern, cowan, nai, snowball, millenium, agouti, revocation,
# Nearest to were: unplugged, yahweh, moralities, carefully, hoya, eea, allergies, goldmine,
# Nearest to can: mchale, isle, maths, kosi, payload, handsel, praxis, mandamus,
# Nearest to is: extension, asis, marijuana, kitab, wenheim, deceived, diem, biollante,
# Nearest to was: pdas, computable, cath, chosenness, carbonyl, toolkit, matched, monastir,
# Nearest to not: dupuy, halide, hampered, lingua, whirling, slack, dae, nandi,
# Nearest to freedom: antihydrogen, renewing, juan, lambasted, hubble, lifo, decompressed, gestapo,
# Nearest to pope: wreaked, swiftly, tshombe, begged, ineffectiveness, lighters, bombastic, nathalie,
# Nearest to behind: basslines, euphemistically, legalisation, misunderstand, shu, beginner, longs, carver,
# Nearest to police: avl, trigram, hematite, arr, laughlin, labourer, rushmore, carman,
# Nearest to applied: babi, backronym, handley, qasr, lim, negativity, cham, senile,
# Nearest to issue: incremental, cadbury, easy, spacewalk, fell, hierarchies, tangenziale, arrogant,
# Nearest to liberal: nafs, rooming, achille, ligature, puma, meteorological, oise, marle,
# Nearest to channel: amur, elliot, ascesis, joysticks, sasaki, qualcomm, glenfinnan, digitalis,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 5.2180 0.1911 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 5.2239 0.1779 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 5.2645 0.1775 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 5.2272 0.1877 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 5.2310 0.1867 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 5.1208 0.1883 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 5.1902 0.1340 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 5.1875 0.1838 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 5.1551 0.1833 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 5.1744 0.1830 sec/batch
# Nearest to a: turnaround, intrigue, eiga, carmilla, whitish, swadesh, surmised, plano,
# Nearest to than: maroc, bridget, acm, capita, apostates, parl, venlo, vas,
# Nearest to history: smitten, dumfries, pretorius, revoluci, zeta, hyperlink, steno, transplant,
# Nearest to were: bolognese, publishing, komodoensis, huntingdon, intimate, lemnos, gilgamesh, aleppo,
# Nearest to can: nmi, schizophrenic, convicted, vomiting, nucleons, henceforward, nilotic, woodwind,
# Nearest to is: nightshade, liabilities, solidified, swath, brin, seniority, ingredient, others,
# Nearest to was: wrestlers, arsenals, fine, katha, averell, convolution, climate, fielded,
# Nearest to not: arterioles, neurophysiology, mazarin, pictorial, hiero, sq, welsh, awakened,
# Nearest to freedom: symbiodinium, democratically, rulings, cholinesterase, outstripped, surveyors, wet, personhood,
# Nearest to pope: udv, sol, awami, disobey, known, ashram, belgrade, princetown,
# Nearest to behind: veganism, robie, thaler, breaches, rewrote, technica, sedative, ting,
# Nearest to police: kutch, mendelian, kelvin, validating, stg, ohm, eighties, circumnavigate,
# Nearest to applied: elfland, linea, frigate, sari, isolationists, zinoviev, cmmi, guaranteed,
# Nearest to issue: linker, tommie, ef, octopussy, curses, fusing, repository, secession,
# Nearest to liberal: dick, oakland, encrusted, gebhard, representations, bilinear, umlauts, ernest,
# Nearest to channel: aguilar, nontheism, savas, quadrennial, strabo, kruskal, maj, kipsigis,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 5.1516 0.1888 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 5.0856 0.1872 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 5.1499 0.1899 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 5.1292 0.1730 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 5.1389 0.1739 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 5.1196 0.1658 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 5.1178 0.1653 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 5.1581 0.1647 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 5.0875 0.1707 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 5.0811 0.1720 sec/batch
# Nearest to a: caliphates, intimidated, partisanship, haba, warnings, brutus, hobbyists, dagmar,
# Nearest to than: contingency, elders, carla, crispus, sheaves, scandalous, marketshare, philosophie,
# Nearest to history: rousseau, vermeer, vittorio, hanging, nicol, legislature, skirmish, harp,
# Nearest to were: masjid, sterg, ames, scrolls, pillows, pino, xxx, enthalpy,
# Nearest to can: immunities, unfounded, cared, ludo, wf, matriarch, ilan, microprograms,
# Nearest to is: whewell, revolts, oracles, nukem, canonization, macron, sunnah, pierson,
# Nearest to was: donatello, sympathies, osceola, dude, revered, cavities, wintered, handsets,
# Nearest to not: german, sawai, downstairs, synchronicity, tco, daytime, raves, mixers,
# Nearest to freedom: halides, proclaim, ads, bandleaders, min, punning, recalls, warriors,
# Nearest to pope: iia, hada, commence, coniferous, need, playful, laborers, pathophysiology,
# Nearest to behind: phrenology, tempura, empower, marches, twig, magnetism, dirk, herman,
# Nearest to police: constants, rrez, goitre, obstruents, recitation, si, hotbed, trotter,
# Nearest to applied: corals, bodkin, headstrong, oceanographer, phallus, bachman, doped, franconia,
# Nearest to issue: massa, breaths, twiggy, cliche, palmeiro, padraig, polypropylene, americano,
# Nearest to liberal: motel, displaying, literatures, oust, blau, oud, bijective, crafted,
# Nearest to channel: mamluks, caused, columba, refinement, dux, inject, unsound, fc,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 5.0587 0.1737 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 5.0644 0.1702 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 5.0703 0.1690 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 5.0662 0.1725 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 5.0211 0.1736 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 5.0491 0.1755 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 5.0754 0.1695 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 5.0277 0.1710 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 5.0514 0.1707 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 5.0520 0.1683 sec/batch
# Nearest to a: iblis, hats, multilingual, behavioural, giraffe, wikipedia, horowitz, exalted,
# Nearest to than: roth, misheard, dosadi, torquato, favored, economists, airstrip, jeffersonian,
# Nearest to history: braces, ecps, srv, warden, errol, resorts, sponges, schiphol,
# Nearest to were: scotton, overloaded, availible, techstep, hostages, postponing, foucault, numerous,
# Nearest to can: oslo, shielded, bongos, embroidery, kiwi, ytterbium, sisal, isolating,
# Nearest to is: eskrima, hoffer, crusade, izanami, basler, ua, revision, moran,
# Nearest to was: ponty, excommunicates, cyberbrain, muppet, formalisms, sidereal, computational, descendants,
# Nearest to not: unprovoked, rss, claude, batavians, otago, hussite, charybdis, everlasting,
# Nearest to freedom: feeding, errico, truths, triumvirate, ballroom, rhodesia, ecologically, glomerulosa,
# Nearest to pope: civilization, tremors, monasticism, lublin, masada, stonehenge, hopkins, chagall,
# Nearest to behind: hawkeye, mochi, kardashev, cellini, wetland, madama, carrot, bridges,
# Nearest to police: pinto, magazine, gandhi, tambourine, supplemented, antipope, nominative, exuberance,
# Nearest to applied: symbiodinium, kindergartens, nsh, fulk, terrier, pay, coulombs, exploitable,
# Nearest to issue: daughter, madam, flippers, presumably, identical, hunger, mcluhan, petomane,
# Nearest to liberal: decoction, slippers, metaphorically, fault, athlon, merton, maoi, acquisitions,
# Nearest to channel: reynard, pcd, unconvincing, tanner, faithless, esp, groceries, slug,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.9644 0.1683 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.9995 0.1671 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 5.0546 0.1718 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.9724 0.1648 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.9827 0.1662 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.9960 0.1645 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 5.0169 0.1659 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.9647 0.1663 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.9802 0.1695 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 5.0039 0.1692 sec/batch
# Nearest to a: emailed, industrialised, hno, daw, patrols, larger, esv, stevie,
# Nearest to than: rakhine, enumerate, lexeme, strategies, redirects, berthollet, arteriosus, depressions,
# Nearest to history: citations, bureaucratic, salamander, carefully, prover, ques, jackpots, reconfiguration,
# Nearest to were: gibbs, marne, forl, reinstating, rhythmic, rowe, refineries, lapsed,
# Nearest to can: lyc, stickers, gila, stationed, veselin, microinstruction, berenguer, articulations,
# Nearest to is: egypt, lippisch, infeasible, hizbullah, diffuse, maquis, jainism, denormalization,
# Nearest to was: coalesce, anaheim, dessalines, wallonia, popularizer, apertura, buboes, huston,
# Nearest to not: newnode, livres, arthropod, bodhi, lytic, sulfide, vat, starlink,
# Nearest to freedom: dept, silhouettes, arachne, argentinean, phrygia, viticulture, taniyama, beauties,
# Nearest to pope: blogger, chronology, augustus, supersonic, suez, leo, quotations, crucially,
# Nearest to behind: biker, tohoku, clonazepam, bodywork, commodities, galatasaray, lansdowne, fanned,
# Nearest to police: amicable, observances, supernovae, april, scout, upon, vidal, geste,
# Nearest to applied: shark, foodborne, correspondents, freebsd, gyroelongated, internship, sluggish, hawley,
# Nearest to issue: fructose, glee, obligations, iconostasis, lenat, specifies, felt, directionally,
# Nearest to liberal: laoghaire, lambert, sauerkraut, bussard, textrm, passport, instabilities, hyakunin,
# Nearest to channel: kiyoshi, cumings, klux, curl, ziv, mooring, rodan, mosig,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.9700 0.1747 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.9774 0.1727 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.9295 0.1716 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.9517 0.1702 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.9310 0.1673 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.9809 0.1665 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.8921 0.1647 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.9080 0.1676 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.9858 0.1666 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.9594 0.1645 sec/batch
# Nearest to a: plate, kantian, coed, wigan, bundles, roofed, attest, help,
# Nearest to than: microorganism, ringers, telescope, krantz, satem, calais, ariadne, bps,
# Nearest to history: hippocratic, modula, counterclockwise, iru, tank, judges, shallower, warden,
# Nearest to were: cve, quip, internationale, rubles, accommodate, pbj, usual, deleting,
# Nearest to can: lempel, kms, buenos, parlay, mccandless, roars, divider, onyx,
# Nearest to is: decayed, bit, trichechus, athenian, conciliator, shivering, immerse, hejira,
# Nearest to was: azam, topical, savant, penning, ankobra, seaweeds, butt, somber,
# Nearest to not: brink, truthful, coonhound, sweaty, bhumi, irma, hoshino, revolutionizing,
# Nearest to freedom: schweickart, flush, pseudalopex, anthropomorphized, sandwich, dots, amides, trustees,
# Nearest to pope: unconfined, lecture, reworkings, what, apertura, galego, relocating, looked,
# Nearest to behind: cathari, svante, hlich, fjord, predicate, climaxed, marshy, sides,
# Nearest to police: reachable, diatomaceous, cad, dubai, miyagi, yeah, vaulted, behaviorism,
# Nearest to applied: harman, malaysian, collins, bossuet, generational, caucus, stiglitz, encouraging,
# Nearest to issue: almagest, stating, leasing, nahin, subnet, dubois, dharmas, universelle,
# Nearest to liberal: tollens, demoted, triple, barbiere, distorting, adidas, quelling, stalls,
# Nearest to channel: pedophiles, kanembu, mears, prophylactic, gently, elvish, hafiz, pulpit,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.9437 0.1673 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.9132 0.1671 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.9328 0.0743 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.9379 0.1665 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.9018 0.1664 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.8593 0.1655 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.9082 0.1645 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.8680 0.1660 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.8986 0.1645 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.9355 0.1646 sec/batch
# Nearest to a: watercourses, berthold, fife, nadine, yong, brl, arrangements, elixir,
# Nearest to than: agora, halo, toms, shootouts, postoperative, annunzio, portrait, procured,
# Nearest to history: narthex, intervene, hove, ludwik, sacrilegious, durrell, horoscopes, benelux,
# Nearest to were: apostrophe, tous, finley, narrows, subordinated, systran, gilboa, cundinamarca,
# Nearest to can: andrzej, laps, crucis, lietuvos, cetaceans, senayan, mainz, saaremaa,
# Nearest to is: laberge, mustard, akkadian, marmalade, bigotry, sabbats, clipper, belle,
# Nearest to was: empress, castlevania, desired, restraint, dissatisfied, repeat, tuft, tapwave,
# Nearest to not: theseus, mortar, enclosing, libby, bronchial, reemerged, codifying, fossiles,
# Nearest to freedom: octet, avro, hardwood, cynic, beams, voicing, herv, etiquette,
# Nearest to pope: liam, heteronormativity, compilations, farinelli, vitro, tennant, isc, continuously,
# Nearest to behind: tolls, reichskanzler, downstairs, geist, scooter, hora, examines, stereotypically,
# Nearest to police: unleashes, gemstones, hyenas, hangs, albicans, sighted, addiscombe, oise,
# Nearest to applied: ssri, hay, muir, strangest, firings, culver, werner, bp,
# Nearest to issue: integer, polymerization, separatism, nome, late, benefactors, interrelated, wielder,
# Nearest to liberal: prefatory, sanskaras, claypool, italiana, joinville, kgb, combustion, drawing,
# Nearest to channel: westport, ahmad, jem, nls, mulroney, ruining, rpgs, imperial,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.9153 0.1685 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.8784 0.1651 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.8867 0.1655 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.8942 0.1660 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.8956 0.1649 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.8913 0.1642 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.8497 0.1638 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.8376 0.1671 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.8664 0.1649 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.8507 0.1649 sec/batch
# Nearest to a: banking, patient, rinaldo, subjective, catamarans, ivens, gonzo, scarred,
# Nearest to than: exorbitant, evangelische, fullmetal, goldeneye, acupuncturists, zelay, chiaroscuro, monomorphism,
# Nearest to history: timer, petrov, rlc, introduce, rud, cope, bakunin, rifting,
# Nearest to were: twiddle, familes, projector, inland, springtime, lippe, ozone, spreading,
# Nearest to can: feininger, gower, rc, rejoined, alcibiades, openvms, southeast, tottenham,
# Nearest to is: soundtrack, nepos, reflectors, convinced, domestic, jafar, artie, dare,
# Nearest to was: banquet, alone, lsap, night, axioms, crete, dhammakaya, archelaus,
# Nearest to not: autodidacts, animators, praetorius, equating, laurier, librarianship, nearer, reboot,
# Nearest to freedom: rashid, mishnayot, idealist, classification, aardvarks, remodeling, hdl, orgies,
# Nearest to pope: augmented, miserably, rinsing, sandburg, espagnole, den, aime, hamlets,
# Nearest to behind: sinks, bitterness, mainz, mustangs, resets, codes, ancus, vitus,
# Nearest to police: marchese, riley, independent, ige, paymaster, chrome, sacro, talmuds,
# Nearest to applied: undeveloped, claudine, halogen, vieri, cleave, hemphill, rourke, tripoli,
# Nearest to issue: outreach, infecting, kiribati, alaskans, since, corridors, ewald, magical,
# Nearest to liberal: aspects, bluebird, perimeter, helped, indictees, michels, uracil, gions,
# Nearest to channel: armies, rebuttal, concacaf, nw, motor, frontiersman, tutsis, welded,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.8662 0.1687 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.8416 0.1643 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.8902 0.1644 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.8539 0.1653 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.8391 0.1706 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.8138 0.1702 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.8438 0.1694 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.8005 0.1713 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.8715 0.1695 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.8186 0.1698 sec/batch
# Nearest to a: rpc, androids, memeplex, gssps, talionis, falconer, grab, flintstones,
# Nearest to than: haec, ndel, abms, tetum, selecting, incandescent, anheuser, encircling,
# Nearest to history: redistribute, vines, tzara, geothermal, decaying, concretes, respondents, insurmountable,
# Nearest to were: jl, minnesotans, professionalism, rebekah, diedrich, testimonium, archaeoastronomy, proclaimed,
# Nearest to can: eug, turf, reassembled, staffordshire, adv, brueys, miskolc, naturally,
# Nearest to is: poem, indemnity, gaye, winterfell, fahrenheit, waddell, imbibed, monotremes,
# Nearest to was: mutual, adenosine, clippings, edema, harps, unu, m, pointers,
# Nearest to not: fireball, scratches, bisects, stoker, vented, peanuts, jeu, pn,
# Nearest to freedom: ulster, cows, founders, sartre, emanations, samples, disruptive, watertight,
# Nearest to pope: scientologists, brochs, caravaggio, nomological, phenol, konservatorium, cricketer, fixed,
# Nearest to behind: peder, comix, conquest, multiplicative, detonators, joslyn, scrip, planner,
# Nearest to police: warhawk, thai, massawa, anointing, each, nanotech, lonely, nectar,
# Nearest to applied: pontificum, dorian, wk, charted, shinogi, expandable, dad, morality,
# Nearest to issue: cheating, somali, nor, mutations, papier, phonological, hallucinatory, tractors,
# Nearest to liberal: australopithecus, holyhead, thoroughbreds, seminars, korean, revival, babylon, mughal,
# Nearest to channel: caxton, laney, fuego, testifies, colons, octagonecologyst, polite, everson,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.8041 0.1716 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.8462 0.1680 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.8560 0.1647 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.8106 0.1675 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.8253 0.1663 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.8522 0.1648 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.8289 0.1668 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.8212 0.1674 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.8000 0.1648 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.8041 0.1647 sec/batch
# Nearest to a: packer, introduction, beached, epoxy, site, specifics, christians, marco,
# Nearest to than: shorts, fuller, excitations, cuic, alkanes, crust, bossuet, asymmetry,
# Nearest to history: small, sociable, interconnect, dci, untitled, xxxix, porphyrin, cobalt,
# Nearest to were: mutilation, autobahn, safavid, mosquitia, bnls, mishap, caldwell, displacement,
# Nearest to can: thermidor, hab, harmonisation, cynthia, clinicians, marie, thracians, wilberforce,
# Nearest to is: fascinating, exerting, taboos, hoover, overline, prawns, desiring, sensual,
# Nearest to was: sudden, shank, recreationally, ferdinand, cr, consanguinity, yeho, soldiers,
# Nearest to not: constitutive, ferocity, arteriosus, taif, apocalypses, avionics, prefaced, praetorian,
# Nearest to freedom: reffered, ethic, rackets, centuriate, lug, sold, harrison, valdemar,
# Nearest to pope: quorums, transubstantiation, oath, kashmir, uruguayan, collaborators, automate, offroad,
# Nearest to behind: renouf, ness, buzzing, resurrecting, entailed, webzine, kwacha, brahman,
# Nearest to police: babel, interconnectedness, cypriot, ciprofloxacin, luxurious, kestrel, solemn, lakatos,
# Nearest to applied: nantes, subtraction, zoologists, nimh, anse, giraffe, displacement, czi,
# Nearest to issue: exchangeable, immunoglobulin, veselin, pave, infuse, fillmore, saidullayev, adventist,
# Nearest to liberal: kernels, gigabit, compagnie, infective, repressive, ll, drywall, operating,
# Nearest to channel: gec, moselle, evaluator, morphogenesis, definiendum, rykodisc, willem, ariel,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.7767 0.1681 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.8547 0.1646 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.7923 0.1634 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.8046 0.1668 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.8277 0.1705 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.8118 0.1663 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.8120 0.1647 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.8085 0.1645 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.7955 0.0266 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.8015 0.1660 sec/batch
# Nearest to a: glycemic, whist, cip, bon, nagpur, oft, quarterbacks, fetches,
# Nearest to than: toothpaste, section, nahum, nonterminal, waldheim, photocopier, allende, ideal,
# Nearest to history: differences, epistemological, shorted, molesworth, ruling, wt, daimyo, milvian,
# Nearest to were: jackpot, vampires, alarc, disturbances, lipoproteins, kn, granada, aft,
# Nearest to can: manger, woolley, hanun, religous, ik, jur, fruitless, mackintosh,
# Nearest to is: rafters, purview, borel, shamrock, royalty, troll, landholding, notaries,
# Nearest to was: rt, freethinkers, irbms, clytemnestra, glauben, uomo, insider, sachet,
# Nearest to not: shining, drugs, divorces, collectivisation, atomic, doping, irish, humorist,
# Nearest to freedom: numb, hoplite, alaric, four, compaq, hamad, governed, super,
# Nearest to pope: necessarily, kagan, medalist, sutcliffe, hg, wallowing, flexi, riverdale,
# Nearest to behind: slovakian, rak, locrian, affan, acropolis, nab, designating, juris,
# Nearest to police: lovin, soissons, usk, weaning, cockpits, mulcahy, debatable, insufficient,
# Nearest to applied: malian, recife, minix, crossbow, kidnap, parsley, heretofore, stedman,
# Nearest to issue: nixon, instrument, kindergartens, assuring, nematode, blew, psyche, pid,
# Nearest to liberal: kovi, physiologic, serially, sympathizers, harmonize, knuth, philosophique, frawley,
# Nearest to channel: assistive, undifferentiated, retelling, arousing, prospered, uneducated, preexisting, cry,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.7656 0.1674 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.7584 0.1650 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.7880 0.1643 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.7468 0.1661 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.7960 0.1662 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.7919 0.1648 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.7940 0.1649 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.7763 0.1647 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.7812 0.1641 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.7951 0.1647 sec/batch
# Nearest to a: jammin, hatti, terminology, ikea, debrecen, fanon, landlady, erasmus,
# Nearest to than: ss, colombia, agavaceae, inactive, resume, foals, gazetteer, republicanism,
# Nearest to history: jamaicans, nanak, stanbul, investigated, garis, quarrels, pranks, mount,
# Nearest to were: positions, paradoxical, fromm, celluloid, underhill, incredibly, macdowell, walking,
# Nearest to can: paints, edward, tunings, pkp, declension, bind, milk, hottest,
# Nearest to is: puranic, burundi, prolong, helmed, forgetting, provenance, strumming, goa,
# Nearest to was: nephritis, nndb, amalek, behave, unload, oceania, stains, canc,
# Nearest to not: uel, mouch, industrialisation, austerlitz, hellenized, saiyan, tailback, pouring,
# Nearest to freedom: kub, polytheistic, watson, ordinates, marmoset, bangui, gunpowder, outbreaks,
# Nearest to pope: metabolism, libri, gaumont, vicksburg, sgml, flanged, parl, impassable,
# Nearest to behind: folio, virginis, dharma, racial, rivera, maturity, geb, propanol,
# Nearest to police: suppression, troopers, persecutor, exp, methionine, professions, kokoschka, ambrosius,
# Nearest to applied: intensity, bentheim, todt, consigned, awadhi, birthday, depicting, grunts,
# Nearest to issue: backups, paolo, pegmatite, highways, committees, login, longrightarrow, regnum,
# Nearest to liberal: vascular, irbm, motivated, camcorder, raft, abolitionists, jani, ritornello,
# Nearest to channel: overseeing, seas, dalai, bellamy, workout, apostate, ineffable, sunrise,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.7975 0.1728 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.7828 0.1690 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.7806 0.1706 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.7615 0.1714 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.7789 0.1690 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.7652 0.1672 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.7800 0.1683 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.7503 0.1672 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.7822 0.1645 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.7628 0.1667 sec/batch
# Nearest to a: dannebrog, her, fencing, vaccinated, isolationists, lastnode, atom, macos,
# Nearest to than: spaceflight, goldberg, lagonda, hogmanay, dashing, highwind, tunnels, dai,
# Nearest to history: anabolism, chemnitz, vidarbha, devo, seedless, shuja, unity, sixes,
# Nearest to were: dioula, banner, smalltalk, america, destructive, stardom, mehta, puns,
# Nearest to can: caleb, privatization, goats, memoir, spader, nac, cormorants, closures,
# Nearest to is: palamas, allergy, amazement, between, laver, quenya, engraver, mcdonald,
# Nearest to was: lincos, offerings, sectioning, sir, suki, reno, gaskets, nitrogen,
# Nearest to not: kornilov, demerara, gogh, salzburg, unsubstantiated, asterism, star, il,
# Nearest to freedom: crops, schwarz, trophies, nails, stereotypes, congress, foals, carolla,
# Nearest to pope: jewishencyclopedia, lockyer, incubate, crewman, greedy, sprockets, minorca, bicycle,
# Nearest to behind: bankruptcies, karami, mitnagdim, uncut, asset, lysine, undergoing, osten,
# Nearest to police: woman, feng, keystroke, ypsilanti, immunosuppression, bsod, delisle, nextstep,
# Nearest to applied: hearers, course, payable, materialist, nkjv, thrusts, manuals, clijsters,
# Nearest to issue: bubba, caruana, kiska, confiscate, ardal, higher, pcs, origine,
# Nearest to liberal: dorris, pundit, kinney, horizons, segregated, acquiesced, udp, bacterial,
# Nearest to channel: theorizes, accursed, chesterton, incited, timepieces, teutoburg, nicomedia, cidr,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.7370 0.1679 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.7528 0.1643 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.7304 0.1643 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.7149 0.1658 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.7549 0.1657 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.7523 0.1646 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.7341 0.1657 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.7634 0.1655 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.7476 0.1645 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.7450 0.1667 sec/batch
# Nearest to a: enumerative, fjord, cnc, brigadier, vitally, luminaries, alphonso, klezmer,
# Nearest to than: rolls, fgm, koza, zel, loudly, monetarist, yue, fluorescence,
# Nearest to history: slider, bahr, staunchly, territoire, cleansing, dalglish, hinders, conjectures,
# Nearest to were: humanism, eponym, sandawe, immunosuppressive, malenkov, appropriated, circular, debaters,
# Nearest to can: colder, pollutants, pair, justify, vermilion, keokuk, payment, ember,
# Nearest to is: comparable, zolt, mujibur, symbolising, does, countable, midler, endeavour,
# Nearest to was: nephites, ecchi, selena, extrapolating, pieced, fainter, lifespan, amman,
# Nearest to not: pavia, lawful, intentional, axelrod, underline, saban, werke, beatified,
# Nearest to freedom: grids, huike, amarok, collapsed, pinguinus, francione, reformists, houma,
# Nearest to pope: amistad, stades, rida, connecting, trinitarians, malmesbury, snell, noor,
# Nearest to behind: bonny, osa, rushen, transcribed, exaggerates, carloman, cliath, conspiratorial,
# Nearest to police: proficiency, dihydrogen, germanium, bey, normalize, weicker, brod, harmondsworth,
# Nearest to applied: sellout, mordor, attuned, honed, conjectures, darren, signification, memoryless,
# Nearest to issue: shrunk, gotti, theorizing, cavendish, hut, criticisms, prestigious, philippe,
# Nearest to liberal: spontaneity, rel, cabrera, colonize, beck, gaetana, mdc, type,
# Nearest to channel: jiu, cmyk, lowered, despatched, nihilists, cagney, kindled, piled,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.7092 0.1697 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.7627 0.1643 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.7607 0.1648 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.7507 0.1681 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.7237 0.1658 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.7404 0.1646 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.6946 0.1659 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.7561 0.1656 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.7238 0.1636 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.7037 0.1643 sec/batch
# Nearest to a: legnica, profess, tropane, wallenstein, pernoud, governess, assemblages, antinomies,
# Nearest to than: prosecuted, wimp, kennedys, autonegotiation, rowdy, okay, overblown, tabulation,
# Nearest to history: aggressive, clin, hauck, gamemasters, animated, dubuque, francium, daniela,
# Nearest to were: cetacea, cue, molise, catalysed, spc, lynched, reduction, burgoyne,
# Nearest to can: islander, happiest, scalability, jonathan, provision, offerings, nathaniel, courted,
# Nearest to is: malevolent, teachings, liberalizing, zairian, stephens, visa, pokey, lorentz,
# Nearest to was: nix, alphabetization, assyrians, sewn, dummy, darker, watering, shadwell,
# Nearest to not: darius, bernicia, poznan, cthulhu, mathbf, nagaoka, oplus, erzherzog,
# Nearest to freedom: whistleblower, roland, bethesda, estado, kurzweil, played, descriptio, hominids,
# Nearest to pope: agrippa, affirm, hester, balinese, littlefield, efron, lakeside, cuitl,
# Nearest to behind: conveniently, priors, pyridine, shrubbery, instructs, searing, tapestry, tamarins,
# Nearest to police: mahogany, haywood, urn, druidic, frazee, flavian, displays, imdb,
# Nearest to applied: klister, diners, boyington, wilmut, claes, ifa, procedural, fashion,
# Nearest to issue: sisal, groton, unida, firework, amg, vera, aux, luthiers,
# Nearest to liberal: cnica, dwarf, citing, instructed, ambivalent, idealism, violoncello, alekhine,
# Nearest to channel: confucianist, soliciting, hajj, brattle, lewes, horseman, king, demonstration,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.7567 0.1669 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.7382 0.1646 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.7248 0.1652 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.7045 0.1663 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.7127 0.1651 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.7392 0.1449 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.7127 0.1705 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.6776 0.1707 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.6951 0.1696 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.7125 0.1901 sec/batch
# Nearest to a: fortaleza, mountain, aquatic, encompass, roque, schillinger, rubbed, unam,
# Nearest to than: lyons, uppsala, mechanical, arabism, stateless, apse, giancarlo, decentralized,
# Nearest to history: athaliah, naguib, viceroys, aspect, whiz, kee, formed, skew,
# Nearest to were: hennecke, tracts, tango, touma, checkmate, retinal, mode, ackerman,
# Nearest to can: helmuth, advent, ed, corry, galesburg, simulates, multiplies, thundering,
# Nearest to is: robeson, kabhi, symbology, musicum, nicholas, rickshaws, sip, vesta,
# Nearest to was: universidade, xenosaga, enlarge, platte, gyroscopic, butlerian, mishra, christus,
# Nearest to not: generalize, guant, onward, qazaqstan, walrus, markers, occurs, silents,
# Nearest to freedom: unions, desiree, students, sidewinders, series, quad, blah, objectivist,
# Nearest to pope: gestalt, ndp, name, mccheese, ctesiphon, fairytale, mechatronics, ringen,
# Nearest to behind: duffield, calculation, venues, sanctioning, pcbs, malle, waltzing, frederic,
# Nearest to police: chaosium, unfinished, penicillin, iglesias, warranted, dictionnaire, san, entertained,
# Nearest to applied: eared, caidin, cb, inconsequential, naqada, shorter, iconography, ambiguous,
# Nearest to issue: grimm, iced, amniotic, laura, open, kanto, demoness, breathy,
# Nearest to liberal: marrakech, periander, ppt, sway, abrasives, gentry, rococo, tibeto,
# Nearest to channel: pyruvate, indica, severin, yield, disarm, jumps, duffield, ebooks,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.6993 0.1897 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 4.7013 0.1789 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.7087 0.1761 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.7150 0.1768 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.6967 0.1732 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.7222 0.1734 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 4.7089 0.1739 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 4.7146 0.1703 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 4.7042 0.1692 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.6872 0.1709 sec/batch
# Nearest to a: jng, ailing, constitutive, josep, anheuser, protein, militarily, rcmp,
# Nearest to than: swastika, season, hooper, prakash, brody, ferment, gilgamesh, scrutiny,
# Nearest to history: timings, gentium, verbally, overlords, demented, playwrights, pda, interquartile,
# Nearest to were: boito, migrated, freeh, gabon, flour, parcel, docs, yoshinkan,
# Nearest to can: echoing, chr, eastman, jade, hajj, wz, pharmacokinetics, aoraki,
# Nearest to is: irregulars, chow, microchips, msx, luca, upgraded, agnostids, annually,
# Nearest to was: paternal, cocoanuts, lots, conjugal, ghor, eurystheus, introductory, give,
# Nearest to not: henning, horatii, hern, lesions, foolishness, nightly, horticulture, determined,
# Nearest to freedom: arbitral, sneak, presenting, evansville, joannes, mathworld, metta, misperception,
# Nearest to pope: bottomed, mountaineers, deserters, irssi, oppressed, aneurysm, patriarchates, exmouth,
# Nearest to behind: amazing, mahathir, expressways, introverted, detested, dendritic, growing, haggadah,
# Nearest to police: conradin, confessions, fets, bai, heschel, destry, visitation, contravariant,
# Nearest to applied: hamming, dandruff, cosmogony, soups, argento, lanthanum, momenta, prix,
# Nearest to issue: cyclo, soir, botvinnik, goscinny, sapkowski, pragmatic, inquisition, liff,
# Nearest to liberal: hynek, mortimer, feudal, storehouse, exited, intracranial, splitflag, cert,
# Nearest to channel: variability, borrelly, ngos, counsel, isaac, jvm, federer, iala,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.6802 0.1752 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.6895 0.1709 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.7030 0.1701 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.6824 0.1688 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.6756 0.1735 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 4.7263 0.1727 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.7096 0.1699 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.6648 0.1704 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.6884 0.1702 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.6652 0.1750 sec/batch
# Nearest to a: caspase, pce, tribune, vehicular, evolution, salvius, totalled, secundus,
# Nearest to than: mdp, holman, bipeds, detroit, oca, oligocene, arbitrator, oaxaca,
# Nearest to history: edgbaston, wandrei, pervez, navel, parametric, fahd, nightmare, daughter,
# Nearest to were: fallout, dandy, bening, exhaustion, shaded, hegelianism, dukes, hypochlorite,
# Nearest to can: asenath, uman, contributions, voiceover, asser, revelations, plotdata, fabian,
# Nearest to is: poirot, toot, wagons, namely, nennius, watercolor, grassroots, repulsion,
# Nearest to was: locking, chalcedon, cleric, kesey, peninsula, excavating, fictional, perfectionism,
# Nearest to not: morey, confirms, miki, enlai, golda, barbary, miscegenation, colonist,
# Nearest to freedom: brazilians, bayh, typhus, unsolicited, renovations, elects, incapacitation, norns,
# Nearest to pope: proprioception, demotic, vaccinated, reassurance, diagnosing, oldsmobile, siegbahn, function,
# Nearest to behind: flipped, disapproved, destabilized, mgh, lol, rescind, fulness, amenable,
# Nearest to police: saginaw, landowner, optically, frightful, piers, acceptors, tenor, tyrell,
# Nearest to applied: baylor, beas, albedo, rykodisc, tandem, keter, jimi, straight,
# Nearest to issue: unalaska, planters, cd, nborn, deposits, synchronisation, shreck, tunnels,
# Nearest to liberal: archival, shoreline, marriages, finntroll, solidify, intervenes, axel, moseley,
# Nearest to channel: toontown, groza, majority, secretaries, rinks, aleutians, workmanship, future,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.7007 0.1868 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.7056 0.1714 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.6673 0.1751 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.6821 0.1687 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.7040 0.1720 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.6761 0.1732 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.6730 0.2004 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 4.6878 0.1898 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.6897 0.1739 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.6864 0.1801 sec/batch
# Nearest to a: results, neophyte, watershed, castration, totoro, labored, gaspard, landmasses,
# Nearest to than: oddities, saavedra, scsi, mythic, globular, emigrate, swedes, suevi,
# Nearest to history: and, eurythmics, exacerbate, lorde, nationalists, simplest, incapacitate, wider,
# Nearest to were: freezer, endangering, maharashtra, denim, attila, vicu, jeffery, unheard,
# Nearest to can: fireman, worldwide, essenes, naively, insurmountable, define, inoue, quatrain,
# Nearest to is: mariners, doctorates, that, purportedly, retrospect, buttocks, wels, modularity,
# Nearest to was: contraceptive, undeveloped, ruska, starfish, jeannette, demon, catastrophism, tajikistan,
# Nearest to not: nausica, maule, suffix, kali, tractates, tsk, lol, magnolia,
# Nearest to freedom: jurist, stretcher, sworn, ritualistic, sq, acceded, lowest, quantifiable,
# Nearest to pope: mammalian, ronnie, kundalini, sawmill, nestorianism, idealized, sheared, sweepers,
# Nearest to behind: fichte, legitimacy, impermanence, polydentate, kingsbridge, spitting, pruning, resists,
# Nearest to police: wieman, acceptor, unpaid, machine, psi, oxen, hallows, mindful,
# ...
# Nearest to issue: rebekah, ltcm, rheology, minimi, magi, chandeliers, dbmss, ponds,
# Nearest to liberal: col, cliffe, ijtihad, begs, grasse, baladan, sync, arming,
# Nearest to channel: trotskyists, morrison, princesses, affiliated, frosted, overkill, anka, aeolian,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.5927 0.1728 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.5831 0.1729 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 4.5827 0.1675 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.5812 0.1714 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.5567 0.1704 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.5747 0.1717 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.5753 0.1710 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 4.5684 0.1734 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.5683 0.1751 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.5672 0.1727 sec/batch
# Nearest to a: wray, directed, eschenbach, franck, gymnast, wailing, coretta, spurious,
# Nearest to than: hetero, bowman, sheng, immunological, ac, functors, moss, ageless,
# Nearest to history: jackals, convertible, velocity, austin, arable, cached, rocky, bricklin,
# Nearest to were: negated, plaintiffs, kok, joyous, testable, giraffa, antipodes, erdrich,
# Nearest to can: functionality, drafting, mcneil, dram, sierpinski, herders, retailing, belong,
# Nearest to is: app, portions, troas, lunatic, hodgkin, jest, mundane, upholds,
# Nearest to was: olympiade, ibid, jovial, dedicates, emblem, elsie, hydrazine, workforce,
# Nearest to not: lamellar, wis, patriarchates, undo, semester, pacheco, acetylcholine, erne,
# Nearest to freedom: brigham, phoneme, esprit, jourdan, quartered, spinet, intuitions, tacticus,
# Nearest to pope: haliotis, saints, triads, shopkeeper, aeolic, materialised, edge, satirizes,
# Nearest to behind: robbins, fermented, scuderia, hel, delos, lukoff, chand, talleyrand,
# Nearest to police: masculinefeminineneuter, lukas, predicated, sheehan, meles, biddle, dormancy, jnana,
# Nearest to applied: borel, eliminate, sungorus, der, searchable, ligeantia, incarnation, freedman,
# Nearest to issue: angering, boethius, kirchhoff, doune, impressively, amanda, gail, ingress,
# Nearest to liberal: beware, proceeded, casta, confluence, goals, immanuel, underlies, hor,
# Nearest to channel: erroneous, kolingba, backups, westerly, denser, destiny, salamis, noa,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.5881 0.1761 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.5798 0.1730 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.5715 0.1765 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.5843 0.1882 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.5784 0.1807 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.5782 0.1782 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.5645 0.1754 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.5680 0.1764 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.5726 0.1786 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.5853 0.1781 sec/batch
# Nearest to a: markets, foia, mattel, nzd, waterline, hurdle, automating, downtime,
# Nearest to than: madsen, greater, pharmacokinetics, henry, cantons, commodity, degenerated, aravalli,
# Nearest to history: subjunctive, soares, reasonableness, search, heures, siu, hsk, porosity,
# Nearest to were: cubs, wasting, louise, ranatunga, colliery, idiosyncrasies, referendum, vinton,
# Nearest to can: allophone, yaoi, subpages, eurozone, strain, brock, dionysus, yoga,
# Nearest to is: sixtus, offenses, dissonant, filtering, uracil, hasek, concerto, tundra,
# Nearest to was: hadley, ainu, implicate, xxii, sankara, serotonin, satirised, cellophane,
# Nearest to not: habilitation, glance, quesada, happenings, theologians, fiore, nylon, objections,
# Nearest to freedom: acute, lackluster, calicut, rockin, kann, nzenberg, tortilla, opera,
# Nearest to pope: bernd, tracks, specializes, badge, lt, dike, cfb, corruptions,
# Nearest to behind: shawnee, papyri, bhaskara, drainage, pasta, allocating, cofactors, pilots,
# Nearest to police: preterist, leppard, gleaned, dell, brosnan, threw, aborted, airfoil,
# Nearest to applied: yasuo, sweetener, krill, accord, antimony, malebranche, boring, djinn,
# Nearest to issue: cramped, srebp, kurz, macromolecules, cebu, lymphoma, finite, football,
# Nearest to liberal: staunchly, kliper, hyi, valuing, zara, dogbert, ejected, brigitte,
# Nearest to channel: darkened, microcosm, farrell, alec, maximilien, mail, linemen, clis,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.5788 0.1793 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.5696 0.1799 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.6106 0.1819 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.5756 0.1825 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.5546 0.1862 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.5820 0.1860 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.5814 0.0892 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.5792 0.1856 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.5676 0.1799 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.5602 0.1844 sec/batch
# Nearest to a: disputing, pumped, einaudi, mauretania, painful, glaciations, corry, leyte,
# Nearest to than: puttnam, sabers, halo, erotic, based, avoidance, napster, rack,
# Nearest to history: terrestris, coronations, govigama, akm, florida, cryo, arthropod, schoolchildren,
# Nearest to were: logistic, diphosphate, heretical, seagulls, encompassing, gourmet, precolonial, adapa,
# Nearest to can: tae, beery, abstracts, cave, undertaken, pdflp, hinterlands, inflating,
# Nearest to is: grokster, consultants, rat, goldberg, appendant, spraying, hierarchically, teleoperation,
# Nearest to was: onlookers, derivations, chhatro, inviolable, newbies, chorded, slenska, discriminating,
# Nearest to not: swarming, frideric, merced, heliocentrism, caring, cleaveland, endo, makes,
# Nearest to freedom: wallets, worden, ucsb, seasoned, roca, cullen, labeling, citizenry,
# Nearest to pope: torontonians, rapidly, mab, nter, retelling, joseph, falsification, ru,
# Nearest to behind: url, imago, advising, unschooling, huddersfield, reservist, eternity, pane,
# Nearest to police: boneyard, marseille, saltzer, bernal, rejoicing, loyalist, recount, blatant,
# Nearest to applied: republished, suffering, zooplankton, external, thorstein, funded, spongiform, leda,
# Nearest to issue: belknap, malibu, helpless, barbuda, sunk, tungusic, foothills, kbit,
# Nearest to liberal: valvular, cosy, executes, advertiser, utterly, diplomats, zealots, ntsc,
# Nearest to channel: fiendish, andrzej, denison, eiga, incantations, vocative, pueblo, ladders,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.5695 0.1829 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.5530 0.1799 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.5792 0.1811 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.5784 0.1800 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.5718 0.1812 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.5644 0.1818 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.5721 0.1822 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.5850 0.1847 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.5713 0.1815 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.5743 0.1808 sec/batch
# Nearest to a: homozygote, triumvirate, congested, lysergic, pensioners, comoving, magnetometer, naming,
# Nearest to than: telephus, israelite, pharisee, trafficking, muslims, tsiolkovsky, creamy, buena,
# Nearest to history: freebase, homeopathy, myoglobin, ekron, peninsulas, bergmann, abrasax, unforgiving,
# Nearest to were: neoconservatism, fireworks, pence, jinnah, exterminated, chickpea, evangelism, ri,
# Nearest to can: refinements, voluminous, cornered, milligan, bp, annoying, counterculture, modernization,
# Nearest to is: nederlandse, ourselves, ucd, goodnight, holiest, arag, bowled, determinative,
# Nearest to was: msg, sobel, supermarkets, survives, seams, ian, disappear, brans,
# Nearest to not: perceptions, phenomenological, mo, verbally, helper, catholic, keeler, distressed,
# Nearest to freedom: griffon, redgrave, assaulting, bayerische, nouveaux, consulting, mortification, cuic,
# Nearest to pope: wife, mammalia, merril, bernal, menuhin, ddd, tortuous, coulthard,
# Nearest to behind: slays, permafrost, eschewed, weaken, fissure, elagabalus, antiaircraft, electrode,
# Nearest to police: jordanians, sipe, ill, blaze, kew, hawkwind, bomba, wheeler,
# Nearest to applied: herbert, philosophiques, indulgence, burgnich, homogenic, goldman, marquardt, gabriel,
# Nearest to issue: qarase, subsidizes, backhand, comit, occured, colonialism, capo, deported,
# Nearest to liberal: tori, associate, poorly, sevastopol, ulaanbaatar, significand, mobilization, sauer,
# Nearest to channel: investigates, hover, psych, gunned, bridegroom, micros, salter, grubb,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 4.5628 0.1752 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.5585 0.1713 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.5595 0.1720 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.5534 0.1710 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.5578 0.1723 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.5567 0.1862 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.5674 0.1998 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.5650 0.1971 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.5756 0.1831 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.5604 0.1960 sec/batch
# Nearest to a: mulder, satisfiable, genevan, hinting, theodicy, callimachus, ige, impeachments,
# Nearest to than: moreno, ug, optimisation, qualitatively, submissive, denver, firepower, barat,
# Nearest to history: daffy, demolished, senex, speciality, masculinity, cfp, firm, budgeted,
# Nearest to were: dimaggio, paradigms, embryogenesis, occ, tribunals, automaton, thunberg, histogram,
# Nearest to can: alphabet, tyne, watling, mwali, toves, convictions, sinope, detract,
# Nearest to is: rites, faramir, migrants, nanosystems, juba, counterfactual, unqualified, meine,
# Nearest to was: ffffff, bandwidth, suzuki, vostok, pens, destructive, chancellery, oecd,
# Nearest to not: lorna, ronaldo, johnston, excl, kab, richard, davidoff, qualia,
# Nearest to freedom: advisor, ampersand, swirling, kortrijk, hark, dorff, garfunkel, alvar,
# Nearest to pope: neill, busing, passengers, rstenberg, kanno, watts, prognosis, emporium,
# Nearest to behind: mataram, kalam, insists, ojibwa, kirtland, lakatos, heydrich, imprint,
# Nearest to police: pentateuch, masque, lemuria, plenitude, overhauled, detoxify, bootstrapping, pricewaterhousecoopers,
# Nearest to applied: millington, transfusions, magnetization, singhasari, kalimantan, livingstone, kwajalein, brasileira,
# Nearest to issue: neurosis, nascent, marred, intellects, indentured, paddy, cataphract, apocalypses,
# Nearest to liberal: unaided, lefkow, wend, barman, obvious, takahata, bib, instructors,
# Nearest to channel: spheroidal, familiaris, icd, hervarar, gough, casablanca, mommsen, anarchists,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.5520 0.1983 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.5500 0.1907 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.5617 0.1835 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.5675 0.1878 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.5541 0.2040 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.5715 0.1723 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.5886 0.1707 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.5670 0.1902 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.5788 0.2073 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.5611 0.1905 sec/batch
# Nearest to a: kid, climb, recognising, jumbled, submerged, symphonie, extremophiles, laments,
# Nearest to than: aut, anse, yoho, mps, verisimilitude, pentagram, precipitates, edvac,
# Nearest to history: heisenberg, langland, pseudopods, mahayana, civitas, unspecified, sweeney, sor,
# Nearest to were: democracy, bolsheviks, deafblind, ecm, empanadas, chiuchow, ytv, seigenthaler,
# Nearest to can: carbons, pwned, lombardo, ssc, wigs, forwarded, linking, guiding,
# Nearest to is: insulin, policies, semitism, atb, amman, consternation, coffins, doctrines,
# Nearest to was: marbled, posek, antofagasta, yogyakarta, julien, macroeconomics, antipodes, congar,
# Nearest to not: sais, experimented, julie, naively, tdt, elagabalus, skater, madsen,
# Nearest to freedom: ringleaders, mercantilist, humid, semiarid, romanovs, archdruid, weaken, microwaves,
# Nearest to pope: ziyi, hugs, cabell, camelids, mettrie, berth, simmered, dermot,
# Nearest to behind: mahoney, circuits, thessalonians, gotta, huxley, ibook, tramiel, authority,
# Nearest to police: riposte, uu, macross, chechens, analog, crb, circe, cordova,
# Nearest to applied: nepali, phonological, boathouse, asturian, settlers, penetration, assigning, satin,
# Nearest to issue: decompressed, repatriation, stew, anagrams, wargaming, kesteven, trespass, fiestas,
# Nearest to liberal: actresses, potency, corsicans, existentialism, pose, outfits, rheumatic, av,
# Nearest to channel: wellman, recovering, rix, dissidents, atherton, propellant, appendices, timbuktu,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.5700 0.1756 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.5901 0.1757 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.5624 0.1776 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.5412 0.1991 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.5698 0.2238 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.5814 0.1841 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.5721 0.1780 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.5581 0.2232 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.5729 0.1986 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.5512 0.1855 sec/batch
# Nearest to a: degrees, xxix, indirection, sucking, futurism, subcultural, scudder, remind,
# Nearest to than: presheaf, remnants, moslems, cinemax, bermontians, arrange, banners, founded,
# Nearest to history: leiter, investigation, statues, feeling, unselfish, executions, scrub, alphonso,
# Nearest to were: carpathian, alkyne, dnieper, dare, franco, xlr, setting, brno,
# Nearest to can: mbeki, cider, mangaverse, debased, majdanek, electromechanical, tropospheric, sensing,
# Nearest to is: fca, culbert, zarqa, logics, legi, protectionism, appealed, greyhounds,
# Nearest to was: ugarte, ille, deluge, alemannia, repetition, metrorail, underwriting, workable,
# Nearest to not: urged, greenaway, limfjord, wageningen, lfhild, gauthier, negara, narrative,
# Nearest to freedom: atticus, conjugation, broadened, corus, births, carbide, panthers, cognates,
# Nearest to pope: vechten, diffusing, ifor, undecidable, fou, relay, refers, refuted,
# Nearest to behind: meshech, vuk, ciii, eunuch, birnbaum, nathaniel, defined, portus,
# Nearest to police: saracens, sephiroth, colonels, blah, metropolis, differentiate, complies, currency,
# Nearest to applied: awestruck, trier, belted, conjectures, formulating, shares, nudity, crevasses,
# Nearest to issue: jaco, constructive, kp, foretells, mentha, frazee, clr, straits,
# Nearest to liberal: decay, gaels, halevi, disappearance, messianic, kronor, sr, compliance,
# Nearest to channel: involuntarily, bcl, freshly, graze, hoppers, marwan, alkaloid, candid,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.5673 0.1728 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.5501 0.1690 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
